# %% [markdown]
# <a id='Top'></a>
# # CLASSIFICATION CHALLENGE
#
# © Explore Data Science Academy
#
# ---

# %% [markdown]
# # Siders Analytics

# %% [markdown]
# <img src="final update .png" usemap="#image-map">
#
# <map name="image-map">
#     <area target="_top" alt="Github_kojosbk" title="Github_kojosbk" href="https://github.com/kojosbk" coords="350,162,283,105" shape="rect">
#     <area target="_top" alt="Linkdin_Silas" title="Linkdin_Silas" href="https://www.linkedin.com/in/silas-bortey-09093575/" coords="33,360,31" shape="circle">
#     <area target="_top" alt="Github Hasanaraji" title="Github Hasanaraji" href="https://github.com/Hasanaraji" coords="746,473,21" shape="circle">
#     <area target="_top" alt="Github MrJunaidu" title="Github MrJunaidu" href="https://github.com/MrJunaidu" coords="627,153,28" shape="circle">
#     <area target="_top" alt="Github Wainaina Gichuhi" title="Github Wainaina Gichuhi" href="https://github.com/pcf26536" coords="747,526,21" shape="circle">
# </map>
#
# #### Note
# To view the links on the picture please press CTRL + the icon to view on windows<br>
# To view the links on the picture please press CMD + the icon to view on Mac

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# ## <a href=#one>1. Introduction</a>
# * <a href=#problemstament>1.1 Problem Statement</a>
# * <a href=#po>1.2 Project Objectives</a>
# * <a href=#dotrain_eda>1.3 Definition of Data Features</a>
# * <a href=#StartingaCometexperiment>1.4 Starting a Comet experiment</a>
#
# ## <a href=#two>2. Import Necessary Libraries</a>
#
# ## <a href=#three>3. Loading Datasets</a>
# * <a href=#three1>3.1 Set Pandas to enable viewing of all columns</a>
# * <a href=#three2>3.2 Check the "Shape" of the data-sets</a>
# * <a href=#three21>3.3 Use the ".column" function to view the columns in our data set</a>
#
# ## <a href=#four>4. Data Preprocessing (Cleaning)</a>
# * <a href=#four1>4.1 Identifying Missing Values</a>
# * <a href=#four2>4.2 Preprocessing the Dataset</a>
# * <a href=#four3>4.3 Most Common Words</a>
#
# ## <a href=#five>5. Exploratory Data Analysis (EDA)</a>
# * <a href=#five1>5.1 Explore the target variable</a>
# * <a href=#five2>5.2 Visualization</a>
#   * <a href=#five21>5.2.1 Checking the distribution of the data</a>
#   * <a href=#five22>5.2.2 Visualize tweet length for each class</a>
#   * <a href=#five23>5.2.3 Quick observations</a>
# * <a href=#five3>5.3 Investigate the feature variable</a>
#   * <a href=#five31>5.3.1 Sentiment Analysis</a>
# * <a href=#five4>5.3 Investigative text analysis</a>
#   * <a href=#five41>5.4.1 visualizing the text by sentiment</a>
#     * Anti Sentiment Class
#     * Neutral Sentiment Class
#     * Pro Sentiment Class
#     * News Sentiment Class
#   * <a href=#five42>5.4.2 Extract the top most used words</a>
#   * <a href=#five43>5.4.3 Quick observation</a>
#   * <a href=#five44>5.4.4 visualizing the data by sentiment</a>
#   * <a href=#five45>5.4.5 Quick observation</a>
# * <a href=#five5>5.5 Named Entity Recognition</a>
#   * <a href=#five51>5.5.1 Named Entity Recognition (Person)</a>
#     * Persons in Pro Sentiment Class
#     * Persons in Anti Sentiment Class
#     * Persons in Neutral Sentiment Class
#     * Persons in News Sentiment Class
#   * <a href=#five52>5.5.2 Named Entity Recognition (Organization)</a>
#     * Organizations in Pro Sentiment Class
#     * Organizations in News Sentiment Class
#     * Organizations in Neutral Sentiment Class
#     * Organizations in Anti Sentiment Class
#
# ## <a href=#six>6. Classification Model</a>
# *  <a href=#six3>6.1 LinearSVC(Support Vector Classifier)</a>
# *  <a href=#six4>6.2 LGBMClassifier(Light Gradient Boosting Machine Classifier)</a>
# *  <a href=#six5>6.3 Logistic Regression</a>
# *  <a href=#six6>6.4 Stochastic Gradient Descent (SGD)</a>
#
# ## <a href=#seven>7. Data or feature Engineering</a>
# * <a href=#seven1>7.1 `TF-IDF`</a>
# * <a href=#seven2>7.2 Pipelines</a>
#   * <a href=#seven21>7.2.1 Building classification pipelines</a>
# * <a href=#seven3>7.3 Training models</a>
#
# ## <a href=#eight>8. Model evalution</a>
# * <a href=#eight3>8.1 Evaluation of LinearSVClassifier</a>
# * <a href=#eight4>8.2 Evaluation of LGBMClassifier</a>
# * <a href=#eight5>8.3 Evaluation of Logistic Regression</a>
# * <a href=#eight6>8.4 Evaluation of SGD Classifier</a>
# * <a href=#eight8>8.8 Model Comparision</a>
#
# ## <a href=#nine>9. Ensemble Method</a>
# * <a href=#nine1>9.1 Method of Heterogeneous Ensembel</a>
#     * <a href=#nine11>9.1.1 Voting classifier</a>
# * <a href=#nine2>9.2 Homogeneous Ensembles</a>
#     * Bagging (AKA Bootstrap Aggregating</a>
# * <a href=#nine3>9.3 Hyperparameter Tuning</a>
#     * <a href=#nine31>9.3.1 Tuning LinearSVC</a>
#     * <a href=#nine32>9.3.2 Tuning Logistic Regression</a>
#     * <a href=#nine33>9.3.3 Tuning Support Vector Classifier</a>
#
# ## <a href=#ten>10. Final model selection</a>
# * <a href=#ten1>10.1 Final evaluation of our best model</a>
# * <a href=#ten2>10.2 ROC Curves and AUC</a>
#
# ## <a href=#eleven>11. Final Predictions</a>
#
# ## <a href=#twelve>12. Submissions</a>
#
# ## <a href=#thirteen>13. Conclusion</a>
#
# ## <a href=#references>14. References</a>

# %% [markdown]
#  <a id="one"></a>
# ## 1. INTRODUCTION
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: INTRODUCTION ⚡ |
# | :--------------------------- |
# | We will address the problem statement and objectives, as well as the classification of data aspects and a brief discussion of the Climate Change Belief Analysis in this part.|

# %% [markdown]
# Companies are built with the goal of reducing one's environmental effect or carbon footprint. They provide ecologically friendly and sustainable goods and services that are in alignment with their principles and goals. They want to know how people feel about climate change and if they believe it is a serious threat.

# %% [markdown]
#  <a id="problemstament"></a>
#
# ### 1.1 Problem Statement
#
# To prevent the drastic effect of climate change and ensure sustainability of the global ecosystem, many companies globally are taking conscious steps towards reducing their carbon footprint. Such companies now tend to offer products and services that are environmentally friendly, sustainable, and in line with their corporate values.
#
# A CDP Global Supply Chain Report projects that companies will lose a total of $1.26 trillion in revenue within the next five years largely due to climate change Our client EDSA is looking to determine how people perceive climate change and whether or not they believe it is a real threat. This would add to their market research efforts in gauging how their product/service may be received.
#
# Our team of data scientists have been tasked with creating a Natural Language Processing model that is able to classify whether or not a person believes in climate change based on their tweet data. This will give the company access to a broad base of consumer sentiment, spanning multiple demographics and geographic categories - thus increasing their insights and informing future marketing strategies.

# %% [markdown]
# <a id="po"></a>
#
# ### 1.2 Project Objectives
#
# * Clean the dataset so that it may be utilized for model development.
#
# * Create a variety of models to identify whether or not someone believes in climate change.
#
# * Using the provided Test Data, assess the model's accuracy in making predictions.
#
# * Pick the best model for determining whether or not someone believes in climate change.
#
# * Advise companies on the best strategy to determine if people believe in climate change and whether it is a serious concern.

# %% [markdown]
# <a id="dodf"></a>
#
# ### 1.3 Definition of Data Features
#
# Chris Bauch of the University of Waterloo received a Canada Foundation for Innovation JELF Grant to acquire these data. The collection includes tweets about climate change that were gathered between April 27, 2015 and February 21, 2018. There were 43943 tweets in total. Each tweet is assigned to one of the classes below:
#
# #### I. Class Description
# * 2 News: the tweet links to factual news about climate change
# * 1 Pro: the tweet supports the belief of man-made climate change
# * 0 Neutral: the tweet neither supports nor refutes the belief of man-made climate change
# * -1 Anti: the tweet does not believe in man-made climate change
#
# #### II. Variable Definitions
# - sentiment: Sentiment of tweet
# - message: Tweet body
# - tweetid: Twitter unique id

# %% [markdown]
# <a id="StartingaCometexperiment"></a>
#
# ### 1.4 Starting a Comet Experiment
# <img src="https://www.comet.ml/images/logo_comet_light.png" width="350" alt="Drawing" style="width: 350px;"/>
#
# We will be using Comet as a form of version control throughout the development of our model

# %%
from comet_ml import Experiment

# %%
# Creating an experiment with your api key
experiment = Experiment(
    api_key="bEFY9Hn1QccermEDT6aTyQMOA",
    project_name="siders-analytics-zf5",
    workspace="kojosbk",
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/kojosbk/siders-analytics-zf5/cd888b05379f4e149f6d89b9cf63ee4a

# %% [markdown]
#  <a id="two"></a>
# ## 2. Import Necessary Libraries
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Import necessary libraries ⚡ |
# | :--------------------------- |
# | We'd be importing all of the necessary libraries for the notebook to run smoothly..|

# %%
# imports for data visualisation

import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()
from textblob import TextBlob
from nltk.probability import FreqDist
from wordcloud import WordCloud, ImageColorGenerator #Pip install wordcloud
import plotly.express as px
import plotly.graph_objects as go

# imports for Natural Language  Processing
import pandas as pd
import numpy as np
import nltk
import string
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.tokenize import TreebankWordTokenizer

# imports model prosessing
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import GridSearchCV

# imports Checking Acuracy
from sklearn.ensemble import BaggingClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import label_binarize

#Model evaluation packages
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 
from sklearn.metrics import accuracy_score, precision_score,  recall_score
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
from scikitplot.metrics import plot_roc, plot_confusion_matrix

# imports for other libraires
import pickle
import warnings
warnings.filterwarnings("ignore")
import en_core_web_sm
import spacy

# %% [markdown]
# <a id="Three"></a>
# ## 3. Loading the Data
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Loading the data ⚡ |
# | :--------------------------- |
# | The data from the `train` file is loaded into a DataFrame in this section.. |
#
# ---

# %% [markdown]
# To start importing our data, we make sure the raw data and notebook file are both in the same folder on our local system. Using the code below, we'll load the train data sets into our notebook. If the files aren't in the same folder, we'll have to point to the directory on our machine . To check that the data has loaded correctly, it is a good practice to call up the loaded data after it has been loaded.
# The information would be saved in two different data frames, one for training and testing and the other for our EDA.

# %%
# Importing the train & test data sets
train = pd.read_csv('train.csv')
test = pd.read_csv('test_with_no_labels.csv')

# EDA Datasets
train_eda = pd.read_csv('train.csv')
test_eda = pd.read_csv('test_with_no_labels.csv')
train_eda.head()
# Out:
#    sentiment                                            message  tweetid
# 0          1  PolySciMajor EPA chief doesn't think carbon di...   625221
# 1          1  It's not like we lack evidence of anthropogeni...   126103
# 2          2  RT @RawStory: Researchers say we have three ye...   698562
# 3          1  #TodayinMaker# WIRED : 2016 was a pivotal year...   573736
# 4          1  RT @SoyNovioDeTodas: It's 2016, and a racist, ...   466954

# %% [markdown]
# <a id=three1></a>
#
# #### 3.1 Set Pandas to enable viewing of all columns
# Due to the length of th content of the message column, pandas cannot display all of them at once by default. While doing EDA and data cleansing, we will need to see all of the columns. When the dataframe is presented, the code below allows us to see the whole set of columns in our data collection.

# %%
# Set option to display all columns
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# <a id=three2></a>
#
# #### 3.2 Check the "Shape" of the data-sets
# As demonstrated by the shape of both datasets, the data has been separated into two sets. The form also shows that the training data set has three columns, but the test data set has just two. Our model is designed to forecast the column that is not present in the test set. We can look for that specific item by looking for the missing entity (Column) in the test data set. After looking at both datasets, the column may be identified as the sentiment column.

# %%
train_eda.shape, test_eda.shape
# Out:
# ((15819, 3), (10546, 2))

# %% [markdown]
# <a id=three21></a>
#
# #### 3.3 Use the ".column" function to view the columns in our data set
# The number of columns and rows in our data set were revealed by the shape method, but the.columns function provides the names of all the columns in the dataframe.

# %%
train_eda.columns, test_eda.columns
# Out:
# (Index(['sentiment', 'message', 'tweetid'], dtype='object'),
#  Index(['message', 'tweetid'], dtype='object'))

# %% [markdown]
# <a id="four"></a>
# ## 4. Data Preprocessing (Cleaning)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# | ⚡ Description: Data Cleaning ⚡ |
# | :--------------------------- |
# | In this phase, we'll convert the data into a readable and desired format, as well as filter out the most relevant information.. |
# #

# %% [markdown]
# <a id=four1></a>
#
# #### 4.1 Identifying Missing Values
#
# It is important to identify the columns that have null entries as null values can affect the performance of our model. The "isnull" function shows the number of null values that are contained in each column of the dataset. This data set is relatively clean as this function shows that only the column "Valencia_pressure" features null values.

# %%
#making a copy of the dataframe
train_data = train.copy()
test_data = test.copy()


#Cheching if there are missing values in the Train dataset
train.isna().sum()
# Out:
# sentiment    0
# message      0
# tweetid      0
# dtype: int64

# %%
#Cheching if there are missing values in the Test dataset
test.isna().sum()
# Out:
# message    0
# tweetid    0
# dtype: int64

# %% [markdown]
# <a id=four2></a>
# ### 4.2 Preprocessing the Dataset
#
# #### Due to the presence of a non numerical column in our datasets, some preprocessing processes must be performed, including:
#
#
# * letter casing :Converting all letters to upper case or lower case is called letter casing.
#
# * Tokenization :Tokenizing refers to the process of converting tweets to tokens. Words separated by spaces in a text are referred to as tokens.
#
# * Noise removal: Unwanted characters such as HTML tags, punctuation marks, special characters, white spaces, and so on are removed.
#
# * Stopwords should be removed because they don't contribute anything to the machine learning model. The nltk library can specify a list of stopwords, or it can be tailored to a particular company.
#
# * Lemmatization: the process of reducing a word's several forms to a single form, such as converting "builds," "building," or "built" to the lemma.
#
# ---

# %%
#removing links
train['message'] = train['message'].str.replace('http\S+|www.\S+', '', case=False)
train['message'] = train['message'].str.replace(r's*https?://S+(s+|$)', ' ',case=False).str.strip()

# %%
def preprocess(text):
    """This function takes in pandas dataframe, removes URL hyperlinks, stopwords, punctuation noises,contractions and lemmatize the text."""

    tokenizer = TreebankWordTokenizer() 
    lemmatizer = WordNetLemmatizer()
    stopwords_list = stopwords.words('english')
    point_noise = string.punctuation + '0123456789'
    
    cleanText = re.sub(r'@[a-zA-Z0-9\_\w]+', '', text)#Remove @mentions
    cleanText = re.sub(r'#[a-zA-Z0-9]+', '', cleanText) #Remove '#' symbols
    cleanText = re.sub(r'RT', '', cleanText)#Remove RT from text
    #Panding Contractions
    # specific
    cleanText = re.sub(r"won\'t", "will not", cleanText)
    cleanText = re.sub(r"can\'t", "can not", cleanText)
    #Panding Contractions
    # general
    cleanText = re.sub(r"n\'t", " not", cleanText)
    cleanText = re.sub(r"\'re", " are", cleanText)
    cleanText = re.sub(r"\'s", " is", cleanText)
    cleanText = re.sub(r"\'d", " would", cleanText)
    cleanText = re.sub(r"\'ll", " will", cleanText)
    cleanText = re.sub(r"\'t", " not", cleanText)
    cleanText = re.sub(r"\'ve", " have", cleanText)
    cleanText = re.sub(r"\'m", " am", cleanText)
    cleanText = ''.join([word for word in cleanText if word not in point_noise]) #Removing punctuations and numbers.
    cleanText = cleanText.lower() #Lowering case
    cleanText = "".join(word for word in cleanText if ord(word)<128) #Removing NonAscii
    cleanText = tokenizer.tokenize(cleanText) #Coverting each words to tokens
    cleanText = [lemmatizer.lemmatize(word) for word in cleanText if word not in stopwords_list] #Lemmatizing and removing stopwords
    cleanText = [word for word in cleanText if len(word) >= 2]
    # cleanText = ' '.join(cleanText)
    #return cleanText
    return cleanText

# %%
#applying the preprocess function
train["message"]=train["message"].apply(preprocess)
train
# Out:
#        sentiment  \
# 0              1
# 1              1
# 2              2
# 3              1
# 4              1
# ...          ...
# 15814          1
# 15815          2
# 15816          0
# 15817         -1
# 15818          0
#
#                                                                                            message  \
# 0      [polyscimajor, epa, chief, think, carbon, dioxide, main, cause, global, warming, wait, via]
# 1                                           [like, lack, evidence, anthropogenic, global, warming]
# 2                                       [researcher, say, three, year, act, climate, change, late]
# 3                                                     [wired, pivotal, year, war, climate, change]
# 4                                 [racist, sexist, climate, change, denying, bigot, leading, poll]
# ...                                                                                            ...
# 15814          [took, material, global, warming, lgbt, right, health, care, hocking, melania, qvc]
# 15815                             [climate, change, could, breaking, millionyearold, relationship]
# 15816  [notiven, nytimesworld, trump, actually, believe, climate, change, rick, perry, join, aide]
# 15817                           [hey, liberal, climate, change, crap, hoax, tie, climate, changed]
# 15818                                                     [climate, change, equation, screenshots]
#
#        tweetid
# 0       625221
# 1       126103
# 2       698562
# 3       573736
# 4       466954
# ...        ...
# 15814    22001
# 15815    17856
# 15816   384248
# 15817   819732
# 15818   806319
#
# [15819 rows x 3 columns]

# %% [markdown]
# <a id=four3></a>
#
# #### 4.3 Most Frequent Words

# %%
from collections import Counter
cnt = Counter()
for message in train['message'].values:
    for word in message:
        cnt[word] += 1
        
cnt.most_common(5)
# Out:
# [('change', 12632),
#  ('climate', 12604),
#  ('global', 3775),
#  ('warming', 3509),
#  ('trump', 2320)]

# %% [markdown]
# <a id="five"></a>
# ## 5. Exploratory Data Analysis (EDA)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Exploratory data analysis ⚡ |
# | :--------------------------- |
# | We'll use a range of strategies in this part to maximize specific insights into our dataset, uncover underlying structure, extract relevant variables, find outliers and anomalies, test assumptions, and establish the optimum estimation parameters. In other words, we want to go deeper into our dataset in order to learn more about its behavior! |
#
# ---

# %% [markdown]
# * Separate Datframes of Tweets for each Sentiment
# ---

# %%
print("See distribution of messages per sentiment : ")
count = train.groupby("sentiment").count()["message"].reset_index().sort_values(by="message", ascending=False)
count.style.background_gradient(cmap="Purples")
# Out:
# See distribution of messages per sentiment :
# <style type="text/css">
# #T_5f113_row0_col0 {
#   background-color: #796eb2;
#   color: #f1f1f1;
# }
# #T_5f113_row0_col1, #T_5f113_row1_col0 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_5f113_row1_col1 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_5f113_row2_col0 {
#   background-color: #c6c7e1;
#   color: #000000;
# }
# #T_5f113_row2_col1 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_5f113_row3_col0, #T_5f113_row3_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_5f113">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f113_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_5f113_level0_col1" class="col_heading level0 col1" >message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f113_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_5f113_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5f113_row0_col1" class="data row0 col1" >8530</td>
#     </tr>
#     <tr>
#       <th id="T_5f113_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_5f113_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_5f113_row1_col1" class="data row1 col1" >3640</td>
#     </tr>
#     <tr>
#       <th id="T_5f113_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_5f113_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_5f113_row2_col1" class="data row2 col1" >2353</td>
#     </tr>
#     <tr>
#       <th id="T_5f113_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_5f113_row3_col0" class="data row3 col0" >-1</td>
#       <td id="T_5f113_row3_col1" class="data row3 col1" >1296</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id=five1></a>
#
# #### 5.1 Explore the Target Variable
#
# For each of our categories, we want to know how our target variable behaves....let's dig in ⛏!

# %%
# Map the target variable name to their code for better understanding

train_eda['Sentiment_Labels']  = train_eda['sentiment'].map({-1: 'Anti',0:'Neutral', 1:'Pro', 2:'News'})

#Confirm the dataset
train_eda.head()
# Out:
#    sentiment  \
# 0          1
# 1          1
# 2          2
# 3          1
# 4          1
#
#                                                                                                                                         message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, what!? https://t.co/yeLvcEFXkC via @mashable
# 1                                                                                It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3                                           #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4                    RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in the polls. #ElectionNight
#
#    tweetid Sentiment_Labels
# 0   625221              Pro
# 1   126103              Pro
# 2   698562             News
# 3   573736              Pro
# 4   466954              Pro

# %% [markdown]
# <a id=five2></a>
#
# ### 5.2 Visualization
# ---

# %% [markdown]
# <a id=five21></a>
#
# #### 5.2.1 Checking the Distribution of the Data

# %%
fig = go.Figure(go.Funnel(
    y = ["Pro","News", "Nuetral", "Anti"],
    x = round(train.sentiment.value_counts(normalize = True) * 100,2)
    ))
fig.update_layout(height=700,width = 900, showlegend=False, title_text="Tweets data distribution by sentiment")
fig.show()

# %%
# Display target distribution

print("Percentage contribution:\n",train_eda.Sentiment_Labels.value_counts(normalize=True)*100)

fig, axes = plt.subplots(ncols=2, 
                         nrows=1, 
                         figsize=(15, 10), 
                         dpi=100)

sns.countplot(train_eda['Sentiment_Labels'], ax=axes[0])

code_labels=['Pro', 'News', 'Neutral', 'Anti']
axes[1].pie(train_eda['Sentiment_Labels'].value_counts(),
            labels= code_labels,
            autopct='%1.0f%%',
            startangle=90,
            explode = (0.1, 0.1, 0.1, 0.1))

fig.suptitle('Dispersion of the target variable', fontsize=20)
plt.show()
# Out:
# Percentage contribution:
#  Pro        53.922498
# News       23.010304
# Neutral    14.874518
# Anti        8.192680
# Name: Sentiment_Labels, dtype: float64

# %%
# Get the length of each message for each class
train_eda['text_length'] = train_eda['message'].apply(lambda x: len(x))
train_eda.head()
# Out:
#    sentiment  \
# 0          1
# 1          1
# 2          2
# 3          1
# 4          1
#
#                                                                                                                                         message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, what!? https://t.co/yeLvcEFXkC via @mashable
# 1                                                                                It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3                                           #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4                    RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in the polls. #ElectionNight
#
#    tweetid Sentiment_Labels  text_length
# 0   625221              Pro          140
# 1   126103              Pro           62
# 2   698562             News          140
# 3   573736              Pro           99
# 4   466954              Pro          122

# %% [markdown]
# <a id=five22></a>
#
# #### 5.2.2 Visualize Tweet Length for each Class

# %%
sns.boxplot(x=train_eda['Sentiment_Labels'], y=train_eda['text_length'], data=train_eda, width = 0.9, color = 'indigo')
sns.set(rc={'figure.figsize':(20,15)})
plt.ylabel('Length of the message')
plt.xlabel('Sentiment class')
plt.title('Message length for each sentiment class')
plt.show()

# %%
# Count the text length for each class type
sns.violinplot(x="Sentiment_Labels", y="text_length", data=train_eda)
plt.ylabel('Lenght of the message')
sns.set(rc={'figure.figsize':(20,15)})
plt.xlabel('Sentiment class')
plt.title('Message length for each sentiment class')
plt.show()

# %% [markdown]
# <a id=five23></a>
#
# ##### 5.2.3 Quick Observations:
# * Our target data, including the feature message, has no missing values.
#
# * There is a significant disparity in sentiment groups.
#
# * Sentiment class '1' (Pro) leads the graph with almost 54% of the vote, while class '-1' (Anti) comes in second with 8%.
#
# * Both the upper and lower bounds of Sentiment Class Pro have outliers.

# %% [markdown]
# <a id=five3></a>
#
# ### 5.3 Investigate the Feature Variable
#
# We want to obtain a better understanding of the message and what it includes at this point in order to draw useful conclusions about our target variable.

# %% [markdown]
# <a id=five31></a>
#
# #### 5.3.1 Sentiment Analysis
#
#
# The process of sentiment analysis finds the underlying emotions in a piece of text. It is the process of categorizing literature into good, negative, or neutral categories. The values range from 1 to -1, with positive emotions decreasing from 1 to -1 and neutral emotion remaining at 0.
#
# ---
# ![Alt_text](https://editor.analyticsvidhya.com/uploads/61727sentiment-fig-1-689.jpeg)

# %%
#Compare the sentiment analysis from raw data


train_eda['polarity']=train_eda['message'].apply(lambda x:
                                             TextBlob(x).sentiment.polarity)

plt.figure(figsize=[10, 8])
plt.hist(train_eda['polarity'], bins=25, linewidth=0)
plt.gca().set(title='Message polarity of raw data',
              ylabel='Frequency', xlabel = 'Sentiment value')
plt.axvline(train_eda['polarity'].mean(), color='black',
            linestyle='dashed', linewidth=1)
plt.axvline(train_eda['polarity'].median(), color='orange',
            linestyle='dashed', linewidth=1)

# %%
#Compare the sentiment analysis from cleaned data

# Convert the cleaned message from list to string
train['message'] = train['message'].str.join(' ')

train['polarity']=train['message'].apply(lambda x:
                                             TextBlob(x).sentiment.polarity)

plt.figure(figsize=[10, 8])
plt.hist(train['polarity'], bins=25, linewidth=0)
plt.gca().set(title='Message polarity of cleaned data',
              ylabel='Frequency', xlabel = 'Sentiment value')
plt.axvline(train['polarity'].mean(), color='black',
            linestyle='dashed', linewidth=1)
plt.axvline(train['polarity'].median(), color='orange',
            linestyle='dashed', linewidth=1)

# %% [markdown]
# <a id=five32></a>
# #### 5.3.2 Observations
#
# - Positively biased feelings, with the mean being higher than the median.
# - The majority of tweets are of a neutral nature.
# - Although cleaned data has a higher mean than raw data, the central tendency for both shows a similar trend.
# - This guarantees that we didn't dilute the behavior of our data during the cleaning process.

# %% [markdown]
# <a id=five4></a>
#
# #### 5.4 Investigative  Text Analysis
# From here, we'll delve further into our text, looking into each term and its frequency of occurrence individually.
#
# ---

# %%
# WordCloud for cleaned data
train['message'] = train['message'].map(lambda x: list(map(str, filter(None, x.split(' '))))) ## Convert the cleaned message from string to list
words = train['message']
allwords = []
for wordlist in words:
    allwords += wordlist
    
mostcommon = FreqDist(allwords).most_common(10000)
wordcloud = WordCloud(width=700, height=700, background_color=
                      'black').generate(str(mostcommon))
fig = plt.figure(figsize=(30,10), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <a id=five41></a>
#
# #### 5.4.1 Visualizing the Text by Sentiment

# %%
# Convert list to strings for each sentiment class
news = train['message'][train_eda['sentiment']==2].str.join(' ')
neutral = train['message'][train_eda['sentiment']==2].str.join(' ')
pro = train['message'][train_eda['sentiment']==2].str.join(' ')
anti = train['message'][train_eda['sentiment']==2].str.join(' ')

#Visualize each sentiment class

fig, axis = plt.subplots(nrows=2, ncols=2, figsize=(18, 12))

news_wordcloud = WordCloud(width=900, height=600, background_color='black', colormap='summer').generate(str(news))
axis[0, 0].imshow(news_wordcloud)
axis[0, 0].set_title('News Class',fontsize=14)
axis[0, 0].axis("off") 

neutral_wordcloud = WordCloud(width=900, height=600, background_color='black', colormap='winter', min_font_size=10).generate(str(neutral))
axis[1, 0].imshow(neutral_wordcloud)
axis[1, 0].set_title('Neutral Class',fontsize=14)
axis[1, 0].axis("off") 

pro_wordcloud = WordCloud(width=900, height=600, background_color='black', colormap='winter', min_font_size=10).generate(str(pro))
axis[0, 1].imshow(pro_wordcloud)
axis[0, 1].set_title('Pro Class',fontsize=14)
axis[0, 1].axis("off") 

anti_wordcloud = WordCloud(width=900, height=600, background_color='black', colormap='winter', min_font_size=10).generate(str(anti))
axis[1, 1].imshow(anti_wordcloud)
axis[1, 1].set_title('Anti Class',fontsize=14)
axis[1, 1].axis("off") 

plt.show()

# %% [markdown]
# * Before completing the exploratory data analysis
#
# Let's have a look at how the sentiment class reacts to climate change through tweets.

# %%
gb = train_eda.groupby('sentiment')
Anti = "".join(gb.get_group(-1)['message'])
Neutral = "".join(gb.get_group(0)['message'])
Pro = "".join(gb.get_group(1)['message'])
News = "".join(gb.get_group(2)['message'])

# %% [markdown]
# * ## Anti Sentiment Class

# %%
print('Show the full_text of 5 Anti Sentiment Class tweets: ')
for tweet in gb.get_group(-1)['message'][100:105]:
    print(tweet)
# Out:
# Show the full_text of 5 Anti Sentiment Class tweets:
# @rambogooner The people saying “don’t look at the sun” are the same people who say climate change is real — and we all know that’s a lie.
# RT @TheFoundingSon: NOAA scientists manipulated temperature data to make global warming seem worse
#
# Who's surprised? Not me
# https://t.co/Rj…
# RT @GeorgiaLogCabin: NOAA's global warming data manipulation https://t.co/flujjaaWUR #Economy #National
# It's really not about science at all, but religious fundamentalism of the climate change cult. With a sprinkling of… https://t.co/vV8L1zTsGq
# RT @MarkACollett: The biggest threat to the environment isn't global warming, it's overpopulation that is fuelled by liberal aid to the thi…

# %% [markdown]
# #### As a result of the above, the Anti Sentiment class thinks that global climate change is a government-engineered hoax.
#
# ---

# %% [markdown]
# * ## Neutral Sentiment Class

# %%
print('Show the full_text of 5 Anti Sentiment Class tweets: ')
for tweet in gb.get_group(0)['message'][1000:1005]:
    print(tweet)
# Out:
# Show the full_text of 5 Anti Sentiment Class tweets:
# RT @superlativemaui: climate change, healthcare, taxes, alzheimer's, supreme court, race and Ã°Å¸ï†Â³Ã¯Â¸ï†Ã¢â‚¬ï†Ã°Å¸Å’Ë† equality, immigration, policing, war, worÃ¢â‚¬Â¦
# #Trumpland .. next, you'll be blaming him for climate change?! Fuck off you reprehensible creature https://t.co/ynLk5jQZ9J
# Making the environment great again...Trump's environment chief says CO2 not main cause of global warming https://t.co/D0KBxKCkjr
# Why do we have to make a deal to do OUR part for climate change? Why can't everyone just do their part for our planet?
# @ValentinoKhan i always start my conversations talking about global warming, it's a real ice-breaker! High five! 🖐

# %% [markdown]
# #### The class of neutral feelings is always neutral; they are neither proponents nor opponents of the subject at hand.
#
# ---

# %% [markdown]
# * ## Pro Sentiment Class

# %%
print('Show the full_text of 5 Anti Sentiment Class tweets: ')
for tweet in gb.get_group(1)['message'][100:105]:
    print(tweet)
# Out:
# Show the full_text of 5 Anti Sentiment Class tweets:
# #SDG13 is a call to take urgent action to combat #climate change and its impacts. Join the movement:Ã¢â‚¬Â¦ https://t.co/BqxZ5ZkBjv
# RT @bradleym4: @JuddLegum Me (to my 14 yo kid): do you believe in climate change?
# Kid: It's a scientific fact, so it doesn't matte…
# RT @StephenSchlegel: she's thinking about how she's going to die because your husband doesn't believe in climate change https://t.co/SjoFoNÃ¢â‚¬Â¦
# When China calls out Donald Trump on climate change, you know itÃ¢â‚¬â„¢s bad https://t.co/ukXyPvuvJf
# RT @billmckibben: 'ExxonMobil has a long history of peddling misinformation on climate change.' @elizkolbert in @NewYorker #ExxonKnew https…

# %% [markdown]
# #### Climate Change Activists make up the majority of the Pro Sentiment Class, and they have a no-holds-barred attitude toward government engagement in climate change.
# ---

# %% [markdown]
# * ## News Sentiment Class

# %%
print('Show the full_text of 5 Anti Sentiment Class tweets: ')
for tweet in gb.get_group(2)['message'][100:105]:
    print(tweet)
# Out:
# Show the full_text of 5 Anti Sentiment Class tweets:
# RT @Wine_Newz: The #Wine industry in #Europe could be in trouble due to global warming, researchers warn https://t.co/1LErjnPpMI
# Trump really doesn't want to face these 21 kids on climate change https://t.co/oHfhg9Gz1O https://t.co/ExhoFHE2KQ
# RT @aggyk: Five Pacific islands lost to rising seas as climate change hits https://t.co/kmnBmFANdw
# NASA is defiantly communicating climate change science despite Trump’s doubts' https://t.co/E3qtwWYV3Z  @NASAClimate Lift ‘em up, y’all!
# RT @Fusion: Peru is suffering its worst floods in recent history—and some scientists say global warming is to blame: https://t.co/3EGbsYVNJq

# %% [markdown]
# #### The news sentiment class is generally curious, and they want to know the truth about climate change.

# %% [markdown]
# <a id=five42></a>
#
# #### 5.4.2 Extracting the top  most used words

# %% [markdown]
# #### - Extract the hastags

# %%
# Get hashtags from raw data
def remove_punc(x):
  '''
  This function takes a string and removes all punctuations from it. and sends it back
  '''
  x = re.sub(r"([^A-Za-z0-9]+)", " ", x)
  return x

nltk.download('stopwords')

", ".join(stopwords.words('english'))
stop_words = set(stopwords.words('english'))


train_eda = pd.read_csv('train.csv')
train_eda['no_stopwords'] = train_eda['message'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

hashtag = [item for item in train_eda['no_stopwords'].str.split() if item[0].startswith('#')]
hashtag = sum(hashtag, [])
count = nltk.FreqDist(hashtag)  
hashtag = pd.DataFrame({'hashtags': list(count.keys()),
                       'count': list(count.values())})
hashtag = hashtag.nlargest(20, columns="count")
hashtag['hashtags'] = hashtag['hashtags'].map(lambda x: remove_punc(str(x))).str.lower().str.strip()
hashtag = hashtag.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
hashtag = (hashtag.groupby("hashtags").agg({"count": np.sum}))
hashtag = hashtag.sort_values(by='count', ascending=True)
hashtag = hashtag.drop(index="")
hashtag.index = hashtag.index.str.capitalize()

hashtag.sort_values(by='count', ascending=False).head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Silas_Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#           count
# hashtags
# Climate     156
# Change      136
# Global       40
# Warming      21
# Trump        15

# %% [markdown]
# #### - Visualizing the data

# %%
fig = px.bar(hashtag, x='count', y=hashtag.index, color='count', title='Top 15 hashtag in the whole data',
             template='plotly_white', labels={'ngram': 'Bigram', 'count': 'Count'}).update_xaxes(categoryorder='total ascending')
fig.show()

# %% [markdown]
# #### - Visualizing in a tree map view

# %%
fig = px.treemap(hashtag, title='Treemap chart by Top 15 Hashtags in the whole data',
                 path=[hashtag.index], values = 'count',color='count', color_continuous_scale=px.colors.sequential.GnBu)
fig.show()

# %% [markdown]
# <a id=five43></a>
#
# ##### 5.4.3 Quick Observation
# - Climate, Change, Global, and warming are the top four hashtags, which is to be expected given that these are the important phrases in ensuring that tweets are easily found
# - According to  [this article](https://www.azocleantech.com/article.aspx?ArticleID=3), there is a link between climate change and global warming, which explains why the hashtags "global" and "warming" are in the top four.

# %% [markdown]
# <a id=five44></a>
#
# #### 5.4.4 Visualizing Text Data by Sentiment

# %%
#Start-off by sorting the dataframe for each sentiment class

# News
news_hashtag = [item for item in train_eda['no_stopwords'][train_eda['sentiment'] == 2].str.split() if item[0].startswith('#')]
news_hashtag = sum(news_hashtag, [])
count = nltk.FreqDist(news_hashtag)  
news_hashtag = pd.DataFrame({'news_hashtags': list(count.keys()),
                       'count': list(count.values())})
news_hashtags = news_hashtag.nlargest(10, columns="count")
news_hashtags = news_hashtags.drop(index=17)
news_hashtags['news_hashtags'] = news_hashtags['news_hashtags'].map(lambda x: remove_punc(str(x))).str.strip()
news_hashtags['news_hashtags'] = news_hashtags['news_hashtags'].str.capitalize()
news_hashtags = news_hashtags.sort_values(by='count', ascending=False)

# Pro
pro_hashtag = [item for item in train_eda['no_stopwords'][train_eda['sentiment'] == 1].str.split() if item[0].startswith('#')]
pro_hashtag = sum(pro_hashtag, [])
count = nltk.FreqDist(pro_hashtag)  
pro_hashtag = pd.DataFrame({'pro_hashtags': list(count.keys()),
                       'count': list(count.values())})
pro_hashtags = pro_hashtag.nlargest(10, columns="count")
pro_hashtags['pro_hashtags'] = pro_hashtags['pro_hashtags'].map(lambda x: remove_punc(str(x))).str.lower().str.strip()
pro_hashtags = (pro_hashtags.groupby("pro_hashtags").agg({"count": np.sum}))
pro_hashtags.index = pro_hashtags.index.str.capitalize()
pro_hashtags = pro_hashtags.sort_values(by='count', ascending=True)

# Neutral
neut_hashtag = [item for item in train_eda['no_stopwords'][train_eda['sentiment'] == 0].str.split() if item[0].startswith('#')]
neut_hashtag = sum(neut_hashtag, [])
count = nltk.FreqDist(neut_hashtag)  
neut_hashtag = pd.DataFrame({'neutral_hashtags': list(count.keys()),
                       'count': list(count.values())})
neutral_hashtags = neut_hashtag.nlargest(10, columns="count")
neutral_hashtags = neutral_hashtags.drop(index=4)
neutral_hashtags['neutral_hashtags'] = neutral_hashtags['neutral_hashtags'].map(lambda x: remove_punc(str(x))).str.lower().str.strip()
neutral_hashtags = (neutral_hashtags.groupby("neutral_hashtags").agg({"count": np.sum}))
neutral_hashtags.index = neutral_hashtags.index.str.capitalize()
neutral_hashtags = neutral_hashtags.sort_values(by='count', ascending=False)

# Anti
anti_hashtag = [item for item in train_eda['no_stopwords'][train_eda['sentiment'] == -1].str.split() if item[0].startswith('#')]
anti_hashtag = sum(anti_hashtag, [])
count = nltk.FreqDist(anti_hashtag)  
anti_hashtag = pd.DataFrame({'anti_hashtags': list(count.keys()),
                       'count': list(count.values())})
anti_hashtags = anti_hashtag.nlargest(10, columns="count")
anti_hashtags['anti_hashtags'] = anti_hashtags['anti_hashtags'].map(lambda x: remove_punc(str(x))).str.strip()
anti_hashtags['anti_hashtags'] = anti_hashtags['anti_hashtags'].str.capitalize()
anti_hashtags = anti_hashtags.sort_values(by='count', ascending=True)

# %% [markdown]
# #### - Ploting the graph

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=2, cols=2, start_cell="bottom-left")
fig = make_subplots(
    rows=2, cols=2,
    specs=[[{}, {}],
           [{}, {}]],
    subplot_titles=("Anti Hashtags","Neutral Hashtags", "Pro Hashtags", "News_Hashtags"))


fig.add_trace(go.Bar(y=anti_hashtags['count'], x= anti_hashtags["anti_hashtags"]),
              row=1, col=1)

fig.add_trace(go.Bar(x=neutral_hashtags.index, y=neutral_hashtags['count']),
              row=1, col=2)

fig.add_trace(go.Bar(x=pro_hashtags.index, y=pro_hashtags["count"]),
              row=2, col=1)

fig.add_trace(go.Bar(x=news_hashtags["news_hashtags"], y=news_hashtags["count"]),
              row=2, col=2)

fig.update_layout(height=700,width = 900, showlegend=False, title_text="Top hashtag comparison for different sentiment classes")

fig.show()

# %% [markdown]
# <a id=five45></a>
#
# ##### 5.4.5 Quick Observation
# - Climate, Change, Global, and warming are the top four hashtags, which is to be expected given that these are the important phrases in ensuring that tweets are easily found
# - According to  [this article](https://www.azocleantech.com/article.aspx?ArticleID=3), there is a link between climate change and global warming, which explains why the hashtags "global" and "warming" are in the top four.
# - The anti hastag group uses the word "faked" as one of their top four most often used words to demonstrate that they do not believe in global warming.

# %% [markdown]
# <a id=five5></a>
#
# ### 5.5 Named Entity Recognition
# - in the section we would determine the names of the persons and organizations who are most frequently mentioned in each sentiment category.
#
# (Named Entity Recognition (NER) is a technique that parses a sentence or a block of text for entities that may be classified as names, organizations, locations, quantities, monetary values, percentages, and so on. Only names, locations, and organizations were incorporated in traditional NER algorithms. They may now be dynamically taught to extract more than only the entities listed earlier. If a chunk of entities is located, NER is a simple but effective method )

# %% [markdown]
# <a id=five51></a>
# #### 5.5.1 Named Entity Recognition (Person)

# %%
#for name entity recognition
train_ner = pd.read_csv('train.csv')

# %%
train_ner['sent_labels']  = train_ner['sentiment'].map({-1: 'Anti',0:'Neutral', 1:'Pro', 2:'News'})
nlp = en_core_web_sm.load()
nlp.max_length = 4000000

# %%
#Removing Urls
train_ner['message'] = train_ner['message'].str.replace('http\S+|www.\S+', '', case=False)
train_ner['message'] = train_ner['message'].str.replace(r's*https?://S+(s+|$)', ' ',case=False).str.strip()

# %%
def preprocess_with_mentions(text):
    """This function takes in pandas dataframe, stopwords, punctuation noises, and lemmatize the text."""

    tokenizer = TreebankWordTokenizer() 
    lemmatizer = WordNetLemmatizer()
    stopwords_list = stopwords.words('english')
    point_noise = string.punctuation + '0123456789'
    
    cleanText = re.sub(r'http[s]?://(?:[A-Za-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9A-Fa-f][0-9A-Fa-f]))+', "", text) #Removing URLs...
    
    cleanText = re.sub(r'#[a-zA-Z0-9]+', '', cleanText) #Remove '#' symbols
    cleanText = re.sub(r'RT', '', cleanText)#Remove RT from text
    
    cleanText = re.sub(r'([https][http][htt][th][ht])', "",cleanText)
    cleanText = ''.join([word for word in cleanText if word not in point_noise]) #Removing punctuations and numbers.
    cleanText = cleanText.lower() #Lowering case
    cleanText = "".join(word for word in cleanText if ord(word)<128) #Removing NonAscii
    cleanText = tokenizer.tokenize(cleanText) #Coverting each words to tokens
    cleanText = [lemmatizer.lemmatize(word) for word in cleanText if word not in stopwords_list] #Lemmatizing and removing stopwords
    cleanText = [word for word in cleanText if len(word) >= 2]
    cleanText = ' '.join(cleanText)
    #return cleanText
    return cleanText

# %%
#Applying function 
train_ner["message"]=train_ner["message"].apply(preprocess_with_mentions)
train_ner
# Out:
#        sentiment  \
# 0              1
# 1              1
# 2              2
# 3              1
# 4              1
# ...          ...
# 15814          1
# 15815          2
# 15816          0
# 15817         -1
# 15818          0
#
#                                                                                               message  \
# 0      polyscimajor epa chief doesnt think carbon dioxide main cause global warming wait via mashable
# 1                                                     like lack evidence anthropogenic global warming
# 2                                          rawstory researcher say three year act climate change late
# 3                                                               wired pivotal year war climate change
# 4                             soynoviodetodas racist sexist climate change denying bigot leading poll
# ...                                                                                               ...
# 15814       ezlusztig took material global warming lgbt right health care theyre hocking melanias qvc
# 15815                        washingtonpost climate change could breaking millionyearold relationship
# 15816                 notiven nytimesworld trump actually believe climate change rick perry join aide
# 15817                             sarasmiles hey liberal climate change crap hoax tie climate changed
# 15818                                  chetcannon kurteichenwalds climate change equation screenshots
#
#        tweetid sent_labels
# 0       625221         Pro
# 1       126103         Pro
# 2       698562        News
# 3       573736         Pro
# 4       466954         Pro
# ...        ...         ...
# 15814    22001         Pro
# 15815    17856        News
# 15816   384248     Neutral
# 15817   819732        Anti
# 15818   806319     Neutral
#
# [15819 rows x 4 columns]

# %%
#PEOPLE INCLUDED IN THE WHOLE DATA SET
train_a = train_ner[train_ner['sent_labels'].isin(['Anti','Neutral','Pro','News'])]
tokens = nlp(''.join(str(train_a['message'].tolist())))
items = [word.text for word in tokens.ents]

person_list = []
for ent in tokens.ents:
    if ent.label_ =='PERSON':
         person_list.append(ent.text)

person_counts = Counter(person_list).most_common()

df_a = pd.DataFrame(person_counts, columns=['person','count'])
df_a.head(5)
#grouping similar names
df_a['person'] = df_a['person'].replace({'hillary':'hillary clinton','clinton':'hillary clinton'})
df_a['person'] = df_a['person'].replace({'scott pruitts':'scott pruitt'}) 
df_a['person'] = df_a['person'].replace({'trumps':'donald trump'})
df_a['person'] = df_a['person'].replace({'trump':'donald trump'})
df_a['person'] = df_a['person'].replace({'gore':'al gore'})
df_a['person'] = df_a['person'].replace({'dana':'dana nuccitelli'})
df_a['person'] = df_a['person'].replace({'putin':'vladimir putin'})
df_a['person'] = df_a['person'].str.capitalize()
df_a = df_a.groupby(df_a['person'], sort=False).sum().sort_values(by=['count'],ascending=[False])
df_a.reset_index(inplace=True)
df_a.head(10)
# Out:
#                person  count
# 0        Scott pruitt    167
# 1     Hillary clinton    136
# 2         Leodicaprio    102
# 3             Al gore     96
# 4  Sethmacfarlane hrc     56
# 5        Donald trump     18
# 6          John kerry     17
# 7   Jerry brown warns     14
# 8          Rick perry     13
# 9    Dana nuccitelli'     12

# %%
#PLOTING THE TREEMAP
fig = px.treemap(df_a.head(10), path=['person'],title='Treemap chart by Top Persons in the whole data',
                 values='count', color= "count")
 
fig.show()

# %% [markdown]
# ### Top 3 persons in the whole data
#
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/Scott_Pruitt_official_portrait.jpg/330px-Scott_Pruitt_official_portrait.jpg" alt="Photo of Scott_Pruitt" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Scott_Pruitt">Scott Pruitt</a> is an American politician and former administrator of the U.S. Environmental Protection Agency. His name is mentioned about 167 times </a>
# </br>
# </br>
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/e/ec/Hillary_Clinton_by_Gage_Skidmore_4_%28cropped%29.jpg" alt="Photo of Clinton" class="GeneratedImage">
# </br>
# <a href="https://en.wikipedia.org/wiki/Hillary_Clinton"> Hillary Clinton</a> is an American politician and lawyer.Her name is mentioned about 136 times </a>
# </br>
# </br>
#
# <img height = "125" width = 100 src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR2q9tvih6sHPAEEbPoCRrWpf2IWVG5IOo5jIxqCA7dgrggsQO5" alt="Photo of Leonardo DiCaprio" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Leonardo_DiCaprio">Leonardo DiCaprio</a>  is an American actor and film producer. Known for his work in biopics and period films, he is the recipient of numerous accolades. His name is mentioned about 102 times </a>
# </br>
# </br>

# %% [markdown]
# ---
# * ### Persons in Pro Sentiment Class

# %%
#PEOPLE INCLUDED IN PRO SENTIMENT
train_pro = train_ner[train_ner['sent_labels'] == 'Pro']
tokens = nlp(''.join(str(train_pro['message'].tolist())))
items = [word.text for word in tokens.ents]

person_list = []
for ent in tokens.ents:
    if ent.label_ =='PERSON':
         person_list.append(ent.text)

person_counts = Counter(person_list).most_common()

df_pro = pd.DataFrame(person_counts, columns=['person','count'])
#grouping similar names
df_pro['person'] = df_pro['person'].replace({'hillary':'hillary clinton','clinton':'hillary clinton'})
df_pro['person'] = df_pro['person'].replace({'scott pruitts':'scott pruitt'}) 
df_pro['person'] = df_pro['person'].replace({'trumps':'donald trump'})
df_pro['person'] = df_pro['person'].replace({'gore':'al gore'})
df_pro['person'] = df_pro['person'].replace({'dana':'dana nuccitelli'})
df_pro['person'] = df_pro['person'].replace({'putin':'vladimir putin'})
df_pro['person'] = df_pro['person'].str.capitalize()
df_pro = df_pro.groupby(df_a['person'], sort=False).sum().sort_values(by=['count'],ascending=[False])
df_pro.reset_index(inplace=True)
df_pro.head(10)
# Out:
#                person  count
# 0        Scott pruitt     95
# 1     Hillary clinton     67
# 2         Leodicaprio     62
# 3             Al gore     56
# 4  Sethmacfarlane hrc     26
# 5        Donald trump     24
# 6          John kerry      8
# 7   Jerry brown warns      8
# 8          Rick perry      8
# 9      Vladimir putin      7

# %%
#PLOTING THE TREEMAP
fig = px.treemap(df_pro.head(10), path=['person'],title='Treemap chart by Top Persons in the Pro Sentiment Section',
                 values='count', color= "count")
 
fig.show()

# %% [markdown]
# ### Top 3 persons in the Pro sentiment data
#
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/Scott_Pruitt_official_portrait.jpg/330px-Scott_Pruitt_official_portrait.jpg" alt="Photo of Scott_Pruitt" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Scott_Pruitt">Scott Pruitt</a> is an American politician and former administrator of the U.S. Environmental Protection Agency. His name is mentioned about 95 times </a>
# </br>
# </br>
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/e/ec/Hillary_Clinton_by_Gage_Skidmore_4_%28cropped%29.jpg" alt="Photo of Clinton" class="GeneratedImage">
# </br>
# <a href="https://en.wikipedia.org/wiki/Hillary_Clinton"> Hillary Clinton</a> is an American politician and lawyer.Her name is mentioned about 67 times </a>
# </br>
# </br>
#
# <img height = "125" width = 100 src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR2q9tvih6sHPAEEbPoCRrWpf2IWVG5IOo5jIxqCA7dgrggsQO5" alt="Photo of Leonardo DiCaprio" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Leonardo_DiCaprio">Leonardo DiCaprio</a>  is an American actor and film producer. Known for his work in biopics and period films, he is the recipient of numerous accolades. His name is mentioned about 62 times </a>
# </br>
# </br>
#
#
# ---
#
# * ### Persons in Anti Sentiment Class

# %%
#PEOPLE INCLUDED IN ANTI SENTIMENT
train_anti = train_ner[train_ner['sent_labels'] == 'Anti']
tokens = nlp(''.join(str(train_anti['message'].tolist())))
items = [word.text for word in tokens.ents]

person_list = []
for ent in tokens.ents:
    if ent.label_ =='PERSON':
         person_list.append(ent.text)

person_counts = Counter(person_list).most_common()

df_anti = pd.DataFrame(person_counts, columns=['person','count'])
#grouping similar names
df_anti['person'] = df_anti['person'].replace({'hillary':'hillary clinton','clinton':'hillary clinton'})
df_anti['person'] = df_anti['person'].replace({'scott pruitts':'scott pruitt'}) 
df_anti['person'] = df_anti['person'].replace({'trumps':'donald trump'})
df_anti['person'] = df_anti['person'].replace({'gore':'al gore'})
df_anti['person'] = df_anti['person'].replace({'dana':'dana nuccitelli'})
df_anti['person'] = df_anti['person'].replace({'putin':'vladimir putin'})
df_anti['person'] = df_anti['person'].str.capitalize()
df_anti = df_anti.groupby(df_a['person'], sort=False).sum().sort_values(by=['count'],ascending=[False])
df_anti.reset_index(inplace=True)
df_anti.head(10)
# Out:
#                person  count
# 0        Scott pruitt     30
# 1     Hillary clinton     11
# 2         Leodicaprio      5
# 3  Sethmacfarlane hrc      3
# 4             Al gore      3
# 5          Rick perry      2
# 6    Dana nuccitelli'      2
# 7      Vladimir putin      2
# 8   Jerry brown warns      2
# 9          John kerry      2

# %%
#PLOTING THE TREEMAP
fig = px.treemap(df_anti.head(10), path=['person'],title='Treemap chart by Top Persons in the Anti Sentiment Section',
                 values='count', color= "count")
 
fig.show()

# %% [markdown]
# ### Top 3 persons in the Anti sentiment data
#
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/Scott_Pruitt_official_portrait.jpg/330px-Scott_Pruitt_official_portrait.jpg" alt="Photo of Scott_Pruitt" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Scott_Pruitt">Scott Pruitt</a> is an American politician and former administrator of the U.S. Environmental Protection Agency. His name is mentioned about 30 times </a>
# </br>
# </br>
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/e/ec/Hillary_Clinton_by_Gage_Skidmore_4_%28cropped%29.jpg" alt="Photo of Clinton" class="GeneratedImage">
# </br>
# <a href="https://en.wikipedia.org/wiki/Hillary_Clinton"> Hillary Clinton</a> is an American politician and lawyer.Her name is mentioned about 11 times </a>
# </br>
# </br>
#
# <img height = "125" width = 100 src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR2q9tvih6sHPAEEbPoCRrWpf2IWVG5IOo5jIxqCA7dgrggsQO5" alt="Photo of Leonardo DiCaprio" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Leonardo_DiCaprio">Leonardo DiCaprio</a>  is an American actor and film producer. Known for his work in biopics and period films, he is the recipient of numerous accolades. His name is mentioned about 5 times </a>
# </br>
# </br>
#
# ---
#
# ---
# * ### Persons in Neutral Sentiment Class

# %%
#PEOPLE INCLUDED IN NEUTRAL SENTIMENT
train_neutral = train_ner[train_ner['sent_labels'] == 'Neutral']
tokens = nlp(''.join(str(train_neutral['message'].tolist())))
items = [word.text for word in tokens.ents]

person_list = []
for ent in tokens.ents:
    if ent.label_ =='PERSON':
         person_list.append(ent.text)

person_counts = Counter(person_list).most_common()

df_neutral = pd.DataFrame(person_counts, columns=['person','count'])
#grouping similar names
df_neutral['person'] = df_neutral['person'].replace({'hillary':'hillary clinton','clinton':'hillary clinton'})
df_neutral['person'] = df_neutral['person'].replace({'scott pruitts':'scott pruitt'}) 
df_neutral['person'] = df_neutral['person'].replace({'trumps':'donald trump'})
df_neutral['person'] = df_neutral['person'].replace({'gore':'al gore'})
df_neutral['person'] = df_neutral['person'].replace({'dana':'dana nuccitelli'})
df_neutral['person'] = df_neutral['person'].replace({'putin':'vladimir putin'})
df_neutral['person'] = df_neutral['person'].str.capitalize()
df_neutral = df_neutral.groupby(df_a['person'], sort=False).sum().sort_values(by=['count'],ascending=[False])
df_neutral.reset_index(inplace=True)
df_neutral.head(10)
# Out:
#                person  count
# 0        Scott pruitt     11
# 1         Leodicaprio      6
# 2     Hillary clinton      6
# 3             Al gore      5
# 4  Sethmacfarlane hrc      4
# 5        Donald trump      4
# 6          John kerry      3
# 7   Jerry brown warns      3
# 8          Rick perry      3
# 9    Dana nuccitelli'      3

# %%
#PLOTING THE TREEMAP
fig = px.treemap(df_neutral.head(10), path=['person'],title='Treemap chart by Top Persons in the neutral Sentiment Section',
                 values='count', color= "count")
 
fig.show()

# %% [markdown]
# ### Top 4 persons in the Neutural sentiment data
#
#
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/Scott_Pruitt_official_portrait.jpg/330px-Scott_Pruitt_official_portrait.jpg" alt="Photo of Scott_Pruitt" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Scott_Pruitt">Scott Pruitt</a> is an American politician and former administrator of the U.S. Environmental Protection Agency. His name is mentioned about 11 times </a>
# </br>
# </br>
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/e/ec/Hillary_Clinton_by_Gage_Skidmore_4_%28cropped%29.jpg" alt="Photo of Clinton" class="GeneratedImage">
# </br>
# <a href="https://en.wikipedia.org/wiki/Hillary_Clinton"> Hillary Clinton</a> is an American politician and lawyer.Her name is mentioned about 6 times </a>
# </br>
# </br>
#
# <img height = "125" width = 100 src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR2q9tvih6sHPAEEbPoCRrWpf2IWVG5IOo5jIxqCA7dgrggsQO5" alt="Photo of Leonardo DiCaprio" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Leonardo_DiCaprio">Leonardo DiCaprio</a>  is an American actor and film producer. Known for his work in biopics and period films, he is the recipient of numerous accolades. His name is mentioned about 6 times </a>
# </br>
# </br>
#
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c5/Al_Gore%2C_Vice_President_of_the_United_States%2C_official_portrait_1994.jpg/330px-Al_Gore%2C_Vice_President_of_the_United_States%2C_official_portrait_1994.jpg" alt="Photo ofAl Gore" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Al_Goreo">Al Gore</a>  is an American politician and environmentalist who served as the 45th vice president of the United States from 1993 to 2001 under president Bill Clinton. His name is mentioned about 5 times </a>
# </br>
# </br>
#
#
# ---
# * ### Persons in News Sentiment Class

# %%
#PEOPLE INCLUDED IN NEWS SENTIMENT
train_news = train_ner[train_ner['sent_labels'] == 'News']
tokens = nlp(''.join(str(train_news['message'].tolist())))
items = [word.text for word in tokens.ents]

person_list = []
for ent in tokens.ents:
    if ent.label_ =='PERSON':
         person_list.append(ent.text)

person_counts = Counter(person_list).most_common()

df_news = pd.DataFrame(person_counts, columns=['person','count'])
#grouping similar names
df_news['person'] = df_news['person'].replace({'hillary':'hillary clinton','clinton':'hillary clinton'})
df_news['person'] = df_news['person'].replace({'scott pruitts':'scott pruitt'}) 
df_news['person'] = df_news['person'].replace({'trumps':'donald trump'})
df_news['person'] = df_news['person'].replace({'gore':'al gore'})
df_news['person'] = df_news['person'].replace({'dana':'dana nuccitelli'})
df_news['person'] = df_news['person'].replace({'putin':'vladimir putin'})
df_news['person'] = df_news['person'].str.capitalize()
df_news = df_news.groupby(df_a['person'], sort=False).sum().sort_values(by=['count'],ascending=[False])
df_news.reset_index(inplace=True)
df_news.head(10)
# Out:
#                person  count
# 0        Scott pruitt     75
# 1     Hillary clinton     26
# 2         Leodicaprio     18
# 3             Al gore     14
# 4  Sethmacfarlane hrc     14
# 5        Donald trump     12
# 6          John kerry      9
# 7   Jerry brown warns      9
# 8    Dana nuccitelli'      7
# 9          Rick perry      7

# %%
#PLOTING THE TREEMAP
fig = px.treemap(df_news.head(10), path=['person'],title='Treemap chart by Top Persons in the News Sentiment Section',
                 values='count', color= "count")
 
fig.show()

# %% [markdown]
# ### Top 4 persons in the News sentiment data
#
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/Scott_Pruitt_official_portrait.jpg/330px-Scott_Pruitt_official_portrait.jpg" alt="Photo of Scott_Pruitt" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Scott_Pruitt">Scott Pruitt</a> is an American politician and former administrator of the U.S. Environmental Protection Agency. His name is mentioned about 75 times </a>
# </br>
# </br>
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/e/ec/Hillary_Clinton_by_Gage_Skidmore_4_%28cropped%29.jpg" alt="Photo of Clinton" class="GeneratedImage">
# </br>
# <a href="https://en.wikipedia.org/wiki/Hillary_Clinton"> Hillary Clinton</a> is an American politician and lawyer.Her name is mentioned about 26 times </a>
# </br>
# </br>
#
# <img height = "125" width = 100 src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR2q9tvih6sHPAEEbPoCRrWpf2IWVG5IOo5jIxqCA7dgrggsQO5" alt="Photo of Leonardo DiCaprio" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Leonardo_DiCaprio">Leonardo DiCaprio</a>  is an American actor and film producer. Known for his work in biopics and period films, he is the recipient of numerous accolades. His name is mentioned about 18 times </a>
# </br>
# </br>
#
# <img height = "125" width = 100 src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c5/Al_Gore%2C_Vice_President_of_the_United_States%2C_official_portrait_1994.jpg/330px-Al_Gore%2C_Vice_President_of_the_United_States%2C_official_portrait_1994.jpg" alt="Photo ofAl Gore" class="GeneratedImage"></br>
# <a href="https://en.wikipedia.org/wiki/Al_Goreo">Al Gore</a>  is an American politician and environmentalist who served as the 45th vice president of the United States from 1993 to 2001 under president Bill Clinton. His name is mentioned about 14 times </a>
# </br>
# </br>

# %% [markdown]
# ### Key observations
#
# * From the data we can see that i profil person are really invested in the topic of global warming in all sentiment
#
# * We can allso see that all these person are persons in power that can help make a real chage in factors that decrease climate change

# %% [markdown]
# <a id=five52></a>
# #### 5.5.2 Named Entity Recognition (ORGANIZATIONS)

# %%
#ORGANIZATIONS INCLUDED IN Pro SENTIMENT
train_oa = train_ner[train_ner['sent_labels'].isin(['Anti','Neutral','Pro','News'])]
tokens = nlp(''.join(str(train_oa['message'].tolist())))
items = [word.text for word in tokens.ents]

org_list = []
for ent in tokens.ents:
    if ent.label_ =='ORG':
        org_list.append(ent.text)

org_counts = Counter(org_list).most_common()

df_org_a = pd.DataFrame(org_counts, columns=['organization','count'])
df_org_a['organization'] = df_org_a['organization'].str.upper()

df_org_a.head(5)
# Out:
#   organization  count
# 0          EPA    540
# 1          CNN    160
# 2           UN    122
# 3  WHITE HOUSE     71
# 4          GOP     51

# %%
#visualizing the data
fig = px.treemap(df_org_a.head(10), path=['organization'],title='Treemap chart by Top organizations in the whole data',
                 values='count', color= "count")
 
fig.show()

# %% [markdown]
# #### The class of neutral feelings is always neutral; they are neither proponents nor opponents of the subject at hand.
#
# ---
# * ### Organizations in Pro Sentiment Class

# %%
#ORGANIZATIONS INCLUDED IN PRO SENTIMENT
train_pro = train_ner[train_ner['sent_labels'] == 'Pro']
tokens = nlp(''.join(str(train_pro['message'].tolist())))
items = [word.text for word in tokens.ents]

org_list = []
for ent in tokens.ents:
    if ent.label_ =='ORG':
        org_list.append(ent.text)

org_counts = Counter(org_list).most_common()

df_org_pro = pd.DataFrame(org_counts, columns=['organization','count'])
df_org_pro['organization'] = df_org_pro['organization'].str.upper()

df_org_pro.head()
# Out:
#   organization  count
# 0          EPA    257
# 1          CNN     60
# 2           UN     41
# 3          GOP     33
# 4         NASA     31

# %%
#PLOTING THE PIE CHART
fig = px.pie(df_org_pro.head(5), values='count', names='organization',
             title='Pie chart by Top organizations in the Pro Sentiment Section',)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# #### The class of neutral feelings is always neutral; they are neither proponents nor opponents of the subject at hand.
#
# ---
# * ### Organizations in News Sentiment Class

# %%
#ORGANIZATIONS INCLUDED IN NEWS SENTIMENT
train_news = train_ner[train_ner['sent_labels'] == 'News']
tokens = nlp(''.join(str(train_news['message'].tolist())))
items = [word.text for word in tokens.ents]

org_list = []
for ent in tokens.ents:
    if ent.label_ =='ORG':
        org_list.append(ent.text)

org_counts = Counter(org_list).most_common()

df_org = pd.DataFrame(org_counts, columns=['organization','count'])
df_org['organization'] = df_org['organization'].str.upper()

df_org.head()
# Out:
#        organization  count
# 0               EPA    248
# 1               CNN     69
# 2                UN     56
# 3       WHITE HOUSE     39
# 4  WASHINGTON POST'     19

# %%
#PLOTING THE PIE CHART
fig = px.pie(df_org.head(5), values='count', names='organization',
             title='Pie chart by Top organizations in the News Sentiment Section',)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# #### The class of neutral feelings is always neutral; they are neither proponents nor opponents of the subject at hand.
#
# ---
# * ### Organizations in Neutral Sentiment Class

# %%
#ORGANIZATIONS INCLUDED IN NEUTRAL SENTIMENT
train_neutral = train_ner[train_ner['sent_labels'] == 'Neutral']
tokens = nlp(''.join(str(train_neutral['message'].tolist())))
items = [word.text for word in tokens.ents]

org_list = []
for ent in tokens.ents:
    if ent.label_ =='ORG':
        org_list.append(ent.text)

org_counts = Counter(org_list).most_common()

df_org_neutral= pd.DataFrame(org_counts, columns=['organization','count'])
df_org_neutral['organization'] = df_org_neutral['organization'].str.upper()

df_org_neutral.head()
# Out:
#   organization  count
# 0          EPA     19
# 1          CNN     18
# 2           UN     16
# 3         HTT'      9
# 4  WHITE HOUSE      7

# %%
#PLOTING THE PIE CHART
fig = px.pie(df_org_neutral.head(5), values='count', names='organization',
             title='Pie chart by Top organizations in the Neutral Sentiment Section',)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# #### The class of neutral feelings is always neutral; they are neither proponents nor opponents of the subject at hand.
#
# ---
# * ### Organizations in Anti Sentiment Class

# %%
#ORGANIZATIONS INCLUDED IN ANTI SENTIMENT
train_anti = train_ner[train_ner['sent_labels'] == 'Anti']
tokens = nlp(''.join(str(train_anti['message'].tolist())))
items = [word.text for word in tokens.ents]

org_list = []
for ent in tokens.ents:
    if ent.label_ =='ORG':
        org_list.append(ent.text)

org_counts = Counter(org_list).most_common()

df_org_anti = pd.DataFrame(org_counts, columns=['organization','count'])
df_org_anti['organization'] = df_org_anti['organization'].str.capitalize()
df_org_anti['organization'] = df_org_anti['organization'].str.upper()


df_org_anti.head()
# Out:
#   organization  count
# 0          EPA     15
# 1          CNN     13
# 2       OXFORD      9
# 3           UN      9
# 4          GOP      3

# %%
#PLOTING THE PIE CHART
fig = px.pie(df_org_anti.head(5), values='count', names='organization',
             title='Pie chart by Top organizations in the Anti Sentiment Section',)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# #### The class of neutral feelings is always neutral; they are neither proponents nor opponents of the subject at hand.
#
# ---

# %% [markdown]
# ### key point to note
#
# <p float="left">
#   <img src="https://cdn.cnn.com/cnn/.e/img/3.0/global/misc/cnn-logo.png" width="300" />
#   <img src="https://pbs.twimg.com/profile_images/3544711733/7ea3d39439d55ffd4ffffa294bad9d14_400x400.jpeg" width="300" />
#   <img src="https://www.uri.org/sites/default/files/styles/teaser/public/media/images/2019/UN%20logo.png" width="300" />
# </p>
#
#
# * All of the above-mentioned groups have a strong presence in the public sphere when it comes to climate change

# %% [markdown]
# <a id="six"></a>
# ## 6. Classification Models
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Classification Models ⚡ |
# | :--------------------------- |
# | In this section, we'll look at different models, try to explain them, and learn about their benefits and drawbacks. |
#
# ---
#
# *  LinearSVC(Support Vector Classifier)<a id='svc'></a>
# *  LGBMClassifier(Light Gradient Boosting Machine Classifier)<a id='LGBM'></a>
# *  Logistic Regression
# *  Stochastic

# %% [markdown]
# <a id="six3"></a>
# ### 6.1 Support Vector Classification(LinearSVC)
# The Support Vector Machine, or SVM, is a linear model that can be used to solve classification and regression issues. It can handle both linear and nonlinear problems and is useful for a wide range of applications. SVM is a basic concept: As seen in the picture below, the method generates a line or hyperplane that divides the data into classes.
#
# ![1*dh0lzq0QNCOyRlX1Ot4Vow.jpeg](https://i.ibb.co/JQqm2vV/A-Group-2-1.png)
#
# To better explain the concept of `SVM` we will look at a case of two classes.
#
# **To choose the most effective line for separating the classes**
#
# The `SVM` method identifies the points from both classes that are closest to the line.
#
# These locations are referred to as support vectors, and the distance between the line and the support vectors is calculated as the margin. Our objective is to increase the profit margin.
#
# The aim in a scenario with more than two classes is to determine the optimum hyperplane that separates them.
# The ideal hyperplane is the one for which the margin is the greatest.
#
# A diagram of how `SVMs` function is shown below.
#
# <p float="left">
#   <img src="https://miro.medium.com/max/880/1*VDATmWG1E1ZNg7hdasOh5g.png" width="300" />
#   <img src="https://miro.medium.com/max/880/1*AMR3v-jCvUMXPUtQskzxmQ.png" width="300" />
#   <img src="https://miro.medium.com/max/880/1*irg_jfdAar9gfe0j-Q04vQ.png" width="300" />
# </p>

# %% [markdown]
# <a id="six4"></a>
# ### 6.2 Light Gradient Boosting Machine(LightGBM)
# LightGBM is a gradient boosting framework that employs a tree-based learning method as well. LightGBM differs from other tree-based algorithms in that it develops trees vertically, whilst other algorithms grow them horizontally. This implies that Light GBM grows trees leaf-by-leaf, whereas other algorithms grow trees level-by-level.
#
# LightGBM will grow the leaf with the greatest delta loss. Leaf-wise algorithms can minimize more loss than level-wise algorithms while expanding the same leaf.
# The diagrams below show how LightGBM and other boosting techniques are implemented.
#
#
# ![1*AZsSoXb8lc5N6mnhqX5JCg.png](https://i.ibb.co/7vtySS2/A-Group-2-2.png)
#
#
# The LightGBM architecture has a number of advantages.
#
# - Increased training efficiency and speed.
# - Memory use is reduced.
# - Increased precision.
# - Parallel and GPU learning are supported.
# - Capable of dealing with massive amounts of data

# %% [markdown]
# <a id="six5"></a>
# ### 6.3 Logistic Regression

# %% [markdown]
# The statistical approach of **logistic regression** is used to predict binary classes. The result or goal variable is a binary variable. The term dichotomous refers to the fact that there are only two potential classifications. It can, for example, be utilized to solve cancer detection issues. It calculates the likelihood of an event occurring.
#
# Logistic regression classifies each data point into the best-estimated class based on its likelihood of belonging to that class.
#
# For linearly separable data, logistic regression has been ranked as the highest performing model, especially for predicting binary data (Yes & NO or 1 & 0), and it performs better when there is no class imbalance.
#
# The sigmoid function is used by logistic regression models to create predictions, as seen in the diagram below:
#
# ![1*QY3CSyA4BzAU6sEPFwp9ZQ.png](https://i.ibb.co/Rb9F7Zr/A-Group-2-3.png)
#
#
#
# Advantages
#
# * Convenient probability scores for observations (probability of each outcome is transformed into a classification);
#
# * Not a major issue if there is collinearity among features (much worse with linear regression).
#
# Disadvantages
#
# * Can overfit when data is unbalanced (i.e.: we have far more observations in one class than the other).
#
# * Doesn't handle large number of categorical variables well.

# %% [markdown]
# <a id="six6"></a>
# ### 6.4 Stochastic Gradient Descent (SGD)

# %% [markdown]
# **Stochastic Gradient Descent (SGD)** is a quick and easy way to fit linear classifiers and regressors to convex loss functions like Support Vector Machines and Logistic Regression. Despite the fact that SGD has been around for a long time in the machine learning field, it has only lately gained traction in the context of large-scale learning.
#
# For each iteration of Stochastic Gradient Descent, a few samples are chosen at random instead of the entire data set.
#
# ![GD-v-SGD.png](https://i.ibb.co/V2XhNkf/A-Group-2-4.png)
#
# The following are some of the benefits of Stochastic Gradient Descent:
#
# * Effectiveness.
#
# * Simplicity of implementation (lots of opportunities for code tuning).
#
#
# The following are some of the drawbacks of Stochastic Gradient Descent:
#
# * A number of hyperparameters are required for SGD, including the regularization parameter and the number of iterations.
#
# * SGD is affected by the size of the features.

# %% [markdown]
# <a id="seven"></a>
# ## 7. Data or Feature Engineering
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Data engineering ⚡ |
# | :--------------------------- |
# | In this section we would be: We will be looking at one of feature selection in text data namely the `tfidfVectorizer`. |
#
# ---
# <a id='seven1'></a>
# ### 7.1 `TF-IDF`
#
# Term Frequency — Inverse Text Frequency (TF-IDF) is a statistic that attempts to better quantify how essential a term is for a document while also considering its relationship to other papers in the same corpus.
# This is done by counting the number of times a term appears in a document as well as the number of times the same word appears in other documents in the corpus.
# `vocabulary_` Is a dictionary that turns each word in the text into a feature index in the matrix, with a feature index for each unique token.

# %% [markdown]
# #### -  Creating our X and y Metrics

# %%
X = train_data['message']
y = train_data['sentiment']
X_test = test_data['message']

# %% [markdown]
# #### - Splitting data into train and validation sets
#
# Separating data into training and validation sets is an important part of evaluating our models.
# In our case we will randomly split the train data into 70% train and 30% validation.
# After our model is trained with the train data we then use it to make predictions for the target using the validation set,Because the data in the validation set already contains known values for the target variable this will make it easy  for us to asses our model's accuracy.

# %%
# Splitting the data into 70% train and 30% validation set
X_train,X_val,y_train,y_val = train_test_split(X,y,test_size=.3,shuffle=True, stratify=y, random_state=42)

# %% [markdown]
# <a id='seven2'></a>
#
# ### 7.2 Pipelines
#
# A 'pipeline' is a tool that applies a set of transformations and a final estimator in a sequential manner. The pipeline's intermediate phases implement fit and transform techniques, whereas the final estimator simply has to implement fit. Pipelines will assist us in transforming the train, validation, and test data, as well as training our models, in our scenario.
#
# Because our models can only process numerical data, the first step is to create a pipeline that converts text data to numeric data. In this notebook, we'll focus on two feature engineering methods that we'll use to convert text data to numeric data: TfidfVectorizer and Word2Vec, and then we'll train our models using these pipelines.
#
# We'll be utilizing 'tfidfVectorizer' to produce features for pipelines.

# %% [markdown]
# <a id='seven21'></a>
#
# #### 7.2.1 Building Classification  Pipelines

# %%
# LinearSVC Pipeline
Lsvc = Pipeline([('tfidf', TfidfVectorizer()),
                     ('scv', LinearSVC()),])
 
# LGBMClassifier Pipeline
lgbm = Pipeline([('tfidf', TfidfVectorizer()), ('lgbm', LGBMClassifier())])

# Logistic Regression pipeline
logreg = Pipeline([('tfidf', TfidfVectorizer()),('logistic', LogisticRegression()),])


# SGD Classifier pipeline
SGD = Pipeline([('tfidf', TfidfVectorizer()), ('SGD', SGDClassifier())])

# %% [markdown]
# <a id='seven3'></a>
#
# #### 7.3 Training Models
#
# Each model is trained using a unique pipeline that takes raw text input, converts it to numeric data, and sets the default parameters for the classifier.

# %%
# training the LinearSVC pipeline
Lsvc.fit(X_train, y_train)  

# training the LGBMClassifier Pipleine
lgbm.fit(X_train, y_train)

# training the logistic regression pipeline
logreg.fit(X_train, y_train)

# training the SGD Classifier
SGD.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('SGD', SGDClassifier())])

# %% [markdown]
# <a id="eight"></a>
# ## 8. Modelling and Evaluation
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Modelling and Evaluation ⚡ |
# | :--------------------------- |
# | In this section we would be:we would be evaluating all the models. |
#
# ---

# %% [markdown]
# ##### - Performance Metrics for model evaluation
#
# The F1 Score, which is the number of true cases for each label, will be used to assess our models.
#
# - ####  Precision
# The ratio of accurately predicted positive observations to total expected positive observations is known as precision.
#
# $$ Precision = \frac{TP}{TP \space + FP} = \frac{TP}{Total \space Predicted \space Positive} $$
#
# - #### Recall
# The capacity of the classifier to discover all the positive samples is known as recall.
#
# $$ Recall = \frac{TP}{TP \space + FN} = \frac{TP}{Total \space Actual \space Positive}$$
#
# - #### F1 Score
# In machine learning, the F1-score is one of the most crucial assessment measures. It effectively summarizes a model's prediction ability by combining two variables that would otherwise be at odds - precision and recall.
#
# (Weighted average of precision and recall.)
#
# $$F_1 = 2 \times \frac {Precision \space \times \space Recall }{Precision \space + \space Recall }$$
#
# [2] "News": Tweets regarding climate change that are based on facts.
#
# [1] "Pro": Tweets in favor of man-made climate change.
#
# [0] "Neutral": tweets are those that neither support nor refute climate change theories.
#
# [-1] "Anti" : tweets are those who do not believe in man-made climate change.

# %% [markdown]
# #### - To evaluate the base models we first start with making predictions for the validation set

# %%
# Making validations set predicions

Lsvc_prediction = Lsvc.predict(X_val) # LinearSVClassifier Predictions
lgbm_prediction = lgbm.predict(X_val) # LGBMClassifier Model predictions
logreg_prediction = logreg.predict(X_val) # Logistic regression predictions
SGD_prediction = SGD.predict(X_val) # SGD Classifier predictions

# %% [markdown]
# <a id="eight3"></a>
# #### 8.1 Evaluation of LinearSVClassifier

# %%
print('\nLinearSVC Model\n', confusion_matrix(y_val, Lsvc_prediction))
# Out:
# LinearSVC Model
#  [[ 185   44  144   16]
#  [  47  278  316   65]
#  [  25   94 2230  210]
#  [   8   19  184  881]]

# %%
labels = ['-1:Anti', '0:Neutral', '1:Pro', '2:News']
print('\nLinearSVC Model\n', classification_report(y_val, Lsvc_prediction,target_names=labels))
plot_confusion_matrix(y_val, Lsvc_prediction, normalize=True,figsize=(8,8),cmap='Blues')
plt.title('LinearSCV Classification')
plt.show()
# Out:
# LinearSVC Model
#                precision    recall  f1-score   support
#
#      -1:Anti       0.70      0.48      0.57       389
#    0:Neutral       0.64      0.39      0.49       706
#        1:Pro       0.78      0.87      0.82      2559
#       2:News       0.75      0.81      0.78      1092
#
#     accuracy                           0.75      4746
#    macro avg       0.72      0.64      0.66      4746
# weighted avg       0.74      0.75      0.74      4746

# %% [markdown]
# ### Important Areas to Note
#
# + We can observe that anti climate has an precision of 70 percent.
#
# + Pro climate has a precision of 77 percent

# %%
# # Visual represetation of of the f1 score for each class
labels = ['-1:Anti', '0:Neutral', '1:Pro', '2:News']
report_svc = classification_report(y_val, Lsvc_prediction, output_dict=True,target_names=labels)
df_svc = pd.DataFrame(report_svc).transpose()
df_svc.drop(['accuracy'], inplace = True)
df_svc.sort_values(by=['f1-score'],ascending=True, inplace = True)
df_svc.drop(['weighted avg','macro avg'])['f1-score'].plot(kind='barh', figsize = (8,8))
plt.xlabel('f1-score')
plt.ylabel('Classes')
plt.yticks(rotation = 40)
plt.title('f1-score per sentiment class for LinearSVC ')
plt.show()

# %% [markdown]
# ### Important Observations
#
# Using the LinearSVC, the f1 score for each sentiment class is shown in the bar graph above.
#
# - We can observe that the LinearSVC model did a far better job at classifying 'Pro climate change' tweets with an f1 score of above 0.8 for the label 1 sentiment class.
#
# - LinearSVC model did a considerably better job identifying 'News' tweets, with the a score level 2 sentiment class of over 0.75.
#
# - We also notice a significant increase in the categorization of "anti-climate change" tweets, with a f1 score of just over 0.5
#
# - The LinearSVC made a minor improvement in the categorization of 'neutral' tweets, but it was considerably outweighed by the gains in other sentiments classes.

# %%
linearSVC_acc = round(accuracy_score(y_val, Lsvc_prediction),4)
print(f'\nOverall accuracy score for LinearSVC Model : {linearSVC_acc}')
linearSVC_f1 = round(f1_score(y_val, Lsvc_prediction, average="weighted"),4)
print(f'\nWeighted avg f1 score for LinearSVC Model : {linearSVC_f1}')
# Out:
# Overall accuracy score for LinearSVC Model : 0.7531
#
# Weighted avg f1 score for LinearSVC Model : 0.7406

# %% [markdown]
# <a id="eight4"></a>
# #### 8.2 Evaluation of LGBMClassifier

# %%
print('\nLightGBM\n', confusion_matrix(y_val, lgbm_prediction))
# Out:
# LightGBM
#  [[ 115   50  201   23]
#  [  24  259  361   62]
#  [  37  114 2191  217]
#  [   7   27  248  810]]

# %%
labels = ['-1:Anti', '0:Neutral', '1:Pro', '2:News']
print('\nLightGBM\n', classification_report(y_val, lgbm_prediction,target_names=labels))
plot_confusion_matrix(y_val, lgbm_prediction, normalize=True,figsize=(8,8),cmap='Blues')
plt.title('LightGBM Classification')
plt.show()
# Out:
# LightGBM
#                precision    recall  f1-score   support
#
#      -1:Anti       0.63      0.30      0.40       389
#    0:Neutral       0.58      0.37      0.45       706
#        1:Pro       0.73      0.86      0.79      2559
#       2:News       0.73      0.74      0.74      1092
#
#     accuracy                           0.71      4746
#    macro avg       0.67      0.57      0.59      4746
# weighted avg       0.70      0.71      0.69      4746

# %% [markdown]
# ### Important Points to Consider
#
# + When compared to 'LinearSVC'  we can find that anti climate and neutral accuracy has reduced by 66%.
#
# + When compared to 'LinearSVC'  the recall values for the pro climate class of 84 percent have decreased.

# %%
# # Visual represetation of of the f1 score for each class
labels = ['-1:Anti', '0:Neutral', '1:Pro', '2:News']
report_lgbm = classification_report(y_val, lgbm_prediction, output_dict=True,target_names=labels)
df_lgbm = pd.DataFrame(report_lgbm).transpose()
df_lgbm.drop(['accuracy'], inplace = True)
df_lgbm.sort_values(by=['f1-score'],ascending=True, inplace = True)
df_lgbm.drop(['weighted avg','macro avg'])['f1-score'].plot(kind='barh', figsize = (8,8))
plt.xlabel('f1-score')
plt.ylabel('Classes')
plt.yticks(rotation = 40)
plt.title('f1-score per sentiment class for LightGBM')
plt.show()

# %% [markdown]
# #### Important Points to Consider
#
# The f1 score for each sentiment class is depicted in the bar graph above using the LightGBM.
#
# - Despite iy gains in identifying 'Pro climate tweets' and 'News,' the LightGBM model still falls short of the 'LinearSVC' model.
#
# - We see a little increase in the classification of 'neutral' tweets when compared to the categorization of 'LinearSVC' tweets.
#
# - Although 'LightGBM' has a lower categorization of 'Anti climate change' tweets than 'LinearSVC,' it still not as good as  LinearSVC

# %%
lGBM_acc = round(accuracy_score(y_val, lgbm_prediction),4)
print(f'\nOverall accuracy score for LightGBM :{lGBM_acc}')
lGBM_f1 = round(f1_score(y_val, lgbm_prediction, average="weighted"),4)
print(f'\nWeighted f1 score for LightGBM :{lGBM_f1}')
# Out:
# Overall accuracy score for LightGBM :0.7111
#
# Weighted f1 score for LightGBM :0.6937

# %% [markdown]
# <a id="eight5"></a>
# #### 8.3 Evaluation of  Logistic Regression

# %%
# Report the confusion matrix
print('\nLogistic Regression\n', confusion_matrix(y_val, logreg_prediction))
# Out:
# Logistic Regression
#  [[ 112   40  216   21]
#  [  25  216  398   67]
#  [  17   55 2299  188]
#  [   1    9  235  847]]

# %%
# Print a classification report
labels = ['-1:Anti', '0:Neutral', '1:Pro', '2:News']
print('\nLogistic Regression\n', classification_report(y_val, logreg_prediction,target_names=labels))
plot_confusion_matrix(y_val, logreg_prediction, normalize=True,figsize=(8,8),cmap='Blues')
plt.title('Logistic Regression Classification')
plt.show()
# Out:
# Logistic Regression
#                precision    recall  f1-score   support
#
#      -1:Anti       0.72      0.29      0.41       389
#    0:Neutral       0.68      0.31      0.42       706
#        1:Pro       0.73      0.90      0.81      2559
#       2:News       0.75      0.78      0.76      1092
#
#     accuracy                           0.73      4746
#    macro avg       0.72      0.57      0.60      4746
# weighted avg       0.73      0.73      0.71      4746

# %% [markdown]
# #### Consider the Following Points
#
# + Anti climate has a 76 percent accuracy LinearSVC  and LGBMClassifier.
#
# + 'LinearSVC,' and 'LGBMClassifier,' the pro climate class has the highest recall values of 89 percent
#
# + In "recall," anti climate is the same as 'LGBMClassifier,' and it has risen in comparison to 'Logistic Regression,' but has fallen in comparison to 'LinearSVC'.

# %%
# # Visual represetation of of the f1 score for each class
labels = ['-1:Anti', '0:Neutral', '1:Pro', '2:News']
report_logreg = classification_report(y_val, logreg_prediction, output_dict=True,target_names=labels)
df_logreg = pd.DataFrame(report_logreg).transpose()
df_logreg.drop(['accuracy'], inplace = True)
df_logreg.sort_values(by=['f1-score'],ascending=True, inplace = True)
df_logreg.drop(['weighted avg','macro avg'])['f1-score'].plot(kind='barh', figsize = (8,8))
plt.xlabel('f1-score')
plt.ylabel('Classes')
plt.yticks(rotation = 40)
plt.title('f1 score per sentiment class for Logistic Regression')
plt.show()

# %% [markdown]
# #### observations (Type here)

# %%
# Print the overall accuracy
logistic_reg_acc = round(accuracy_score(y_val, logreg_prediction),4)
print('\nLogistic Regression accuracy Score\n', logistic_reg_acc)
logistic_reg_f1 = round(f1_score(y_val, logreg_prediction, average="weighted"),4)
print('\nLogistic Regression weighted f1 score\n', logistic_reg_f1)
# Out:
# Logistic Regression accuracy Score
#  0.732
#
# Logistic Regression weighted f1 score
#  0.7068

# %% [markdown]
# <a id="eight6"></a>
# #### 8.4 Evaluation of SGD Classifier

# %%
# Confusion matrix for the random forest classifier
print('\nSGD Classifier\n', confusion_matrix(y_val, SGD_prediction))
# Out:
# SGD Classifier
#  [[ 163   35  168   23]
#  [  33  235  362   76]
#  [  22   62 2263  212]
#  [   6   14  197  875]]

# %%
# The classification report 
labels = ['-1:Anti', '0:Neutral', '1:Pro', '2:News']
print('\nSGD Classifier  Classification report :\n', classification_report(y_val, SGD_prediction,target_names=labels))
plot_confusion_matrix(y_val, SGD_prediction, normalize=True,figsize=(8,8),cmap='Blues')
plt.title('Logistic Regression Classification')
plt.show()
# Out:
# SGD Classifier  Classification report :
#                precision    recall  f1-score   support
#
#      -1:Anti       0.73      0.42      0.53       389
#    0:Neutral       0.68      0.33      0.45       706
#        1:Pro       0.76      0.88      0.82      2559
#       2:News       0.74      0.80      0.77      1092
#
#     accuracy                           0.75      4746
#    macro avg       0.73      0.61      0.64      4746
# weighted avg       0.74      0.75      0.73      4746

# %% [markdown]
# #### Key Observations
#
# + Anti and neutral are more accurate than 'LinearSVC,' LGBMClassifier,' and 'Logistic Regression.
#
# + The recall value for the pro climate class is 88 percent, which is greater than'Logistic Regression,' when compared to 'LinearSVC,' and 'LGBMClassifier.'
#
# + Anti climate has a greater recall than  'LGBMClassifier,' and 'Logistic Regression,' but not as high as 'LinearSVC.'
#
# + Neutral's recall is lower than that of 'LinearSVC,' and 'LGBMClassifier,' but greater than that of 'Logistic Regression.'

# %%
# # Visual represetation of of the f1 score for each class
labels = ['-1:Anti', '0:Neutral', '1:Pro', '2:News']
report_sgd = classification_report(y_val, SGD_prediction, output_dict=True,target_names=labels)
df_sgd = pd.DataFrame(report_sgd).transpose()
df_sgd.drop(['accuracy'], inplace = True)
df_sgd.sort_values(by=['f1-score'],ascending=True, inplace = True)
df_sgd.drop(['weighted avg','macro avg'])['f1-score'].plot(kind='barh', figsize = (8,8))
plt.xlabel('f1-score')
plt.ylabel('Classes')
plt.yticks(rotation = 40)
plt.title('f1-score per sentiment class for SGD')
plt.show()

# %%
# Checking the accuracy score
sgd_acc = round(accuracy_score(y_val, SGD_prediction),4)
print('\nSGD Classifier accuracy Score :\n', sgd_acc)

# Checking the f1_score report for the decison tree model
sgd_f1 = round(f1_score(y_val, SGD_prediction, average="weighted"),4)
print('\nSGD weighted avg f1_score :\n', sgd_f1)
# Out:
# SGD Classifier accuracy Score :
#  0.745
#
# SGD weighted avg f1_score :
#  0.7266

# %% [markdown]
# <a id="eight8"></a>
# ### 8.8 Model Comparision
#
# Model comparison by accuracy and macro f1_score

# %%
# Creating a dataframe with our models and their performances metrics
classifier_scores = {'Classifiers':['LinearSVC','LGBM','Logistic Regression','Stochastic Gradient Descent'],
                    'Accuracy':[linearSVC_acc,lGBM_acc,logistic_reg_acc, sgd_acc],
                     'Weighted avg f1 Score':[linearSVC_f1,lGBM_f1,logistic_reg_f1, sgd_f1]}
df= pd.DataFrame(classifier_scores)
df.sort_values(by=['Weighted avg f1 Score'],ascending=False, inplace = True)
df
# Out:
#                    Classifiers  Accuracy  Weighted avg f1 Score
# 0                    LinearSVC    0.7531                 0.7406
# 3  Stochastic Gradient Descent    0.7450                 0.7266
# 2          Logistic Regression    0.7320                 0.7068
# 1                         LGBM    0.7111                 0.6937

# %%
df.set_index(df['Classifiers'], inplace = True)
df.drop(['Classifiers'],axis = 1)
df.plot(kind='barh', figsize = (8,8),colormap='coolwarm_r')
plt.xlabel('Score')
plt.yticks(rotation = 45)
plt.title('Classifier Perfomance')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %% [markdown]
# #### Final Observations

# %% [markdown]
# We can see a comparison of the 4 models we've tried so far based on their 'accuracy score' and accompanying 'weighted f1 score' in the upper bar graph.
#
# - We can see that our top three best performing models are 'LinearSVC,"Stochastic Gradient Descent,' and 'Logistic Regression,' which we will apply in ensemble approaches to try to enhance our findings.
#
# - The 'lgbm' classifier performs the poorest at categorizing tweets
#
# **With an accuracy score of 0.74 and a weighted f1 score of 0.73, LinearSVC is the highest performing model out of the 4 models we've tried so far**

# %% [markdown]
# <a id="nine"></a>
# ## 9 Ensemble Methods
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Ensemble Methods ⚡ |
# | :--------------------------- |
# | Ensemble learning is the practice of combining many models to improve overall model performance in machine learning. Ensembles are made up of several **heterogeneous or homogeneous** models that have all been trained on the same dataset. Each of these models is used to make predictions based on the same input, which are then combined in some way (for example, by taking the mean) to provide the final result.. |

# %% [markdown]
# <a id='nine1'></a>
#
# ### 9.1 Method of Heterogeneous Ensembel
# This sort of ensemble comprises of several types of models, so we can use it to include pretty much any classification model we want. In our instance, however, we'll just use our top three performing models, which are 'LinearSVC, Stochastic Gradient Descent, Logistic Regression.'
#
# The 'Voting classifier' is the Heterogeneous ensemble approach we'll look at.

# %% [markdown]
# <a id='nine11'></a>
# #### 9.1.1 Voting classifer
#
# Voting involves combining individual model outputs through a kind of "[majority rule](https://en.wikipedia.org/wiki/Majority_rule)" paradigm.
# The diagram below shows how the `Voting Classifier` works
# ![ud382N9.png](https://i.ibb.co/SBTNrV7/A-Group-2.jpg)

# %%
# Define the models which we'll include in our ensemble. 
# We pass a list of tuples, which each have a string identifier for the
# model (arbitrary choice), along the actual instantiated sklearn model.  
models = [("LinearSVC",Lsvc),("SGD",SGD),("Logistric Regression",logreg)]

# Specify weights for weighted model averaging
model_weightings = np.array([0.1,0.3,0.6])

# building the voting classifier
Voting_classifier = VotingClassifier(estimators=models,weights=model_weightings)

# %%
# training the voting classifier
Voting_classifier.fit(X_train, y_train)
# Out:
# COMET ERROR: Failed to extract parameters from estimator
# VotingClassifier(estimators=[('LinearSVC',
#                               Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                               ('scv', LinearSVC())])),
#                              ('SGD',
#                               Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                               ('SGD', SGDClassifier())])),
#                              ('Logistric Regression',
#                               Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                               ('logistic',
#                                                LogisticRegression())]))],
#                  weights=array([0.1, 0.3, 0.6]))

# %%
voting_prediction = Voting_classifier.predict(X_val) # Voting Classifier predictions

# %%
# The classification report 
labels = ['-1:Anti', '0:Neutral', '1:Pro', '2:News']
print('\nVoting Classifier  Classification report :\n', classification_report(y_val, voting_prediction,target_names=labels))
plot_confusion_matrix(y_val, voting_prediction, normalize=True,figsize=(8,8),cmap='Blues')
plt.title('Voting Classifier Classification')
plt.show()
# Out:
# Voting Classifier  Classification report :
#                precision    recall  f1-score   support
#
#      -1:Anti       0.72      0.29      0.41       389
#    0:Neutral       0.68      0.31      0.42       706
#        1:Pro       0.73      0.90      0.81      2559
#       2:News       0.75      0.78      0.76      1092
#
#     accuracy                           0.73      4746
#    macro avg       0.72      0.57      0.60      4746
# weighted avg       0.73      0.73      0.71      4746

# %%
# Visual represetation of of the f1 score for each class
labels = ['-1:Anti', '0:Neutral', '1:Pro', '2:News']
report_voting = classification_report(y_val, voting_prediction, output_dict=True,target_names=labels)
df_voting = pd.DataFrame(report_voting).transpose()
df_voting.drop(['accuracy'], inplace = True)
df_voting.sort_values(by=['f1-score'],ascending=True, inplace = True)
df_voting.drop(['weighted avg','macro avg'])['f1-score'].plot(kind='barh', figsize = (8,8))
plt.xlabel('f1-score')
plt.ylabel('Classes')
plt.yticks(rotation = 40)
plt.title('f1-score per sentiment class for the voting classifier')
plt.show()

# %%
# Checking the accuracy score
voting_acc = round(accuracy_score(y_val, voting_prediction),4)
print(f'\nOverall accuracy for the Voting Classifier :{voting_acc}')
voting_f1 = round(f1_score(y_val, voting_prediction, average="weighted"),4)
print(f'\nWeighted avg f1 score for the Voting Classifier :{voting_f1}')
# Out:
# Overall accuracy for the Voting Classifier :0.732
#
# Weighted avg f1 score for the Voting Classifier :0.7068

# %% [markdown]
# <a id='nine2'></a>
# ### 9.2 Homogeneous Ensembles
# These are all models of the same kind. As a result, controlling the number of predictors or the percentage of data provided to each model in the ensemble is a typical technique to create variety in model performance in these circumstances. This is similar to what happens in a random forest.
#
# **Bagging** and **boosting** are two of the most prevalent strategies for merging models in this fashion.
#
# * #### Bagging (AKA Bootstrap Aggregating)
#
# Bagging is the process of training the ensemble's models on distinct subsets of the training data. Particularly on subsets from the training data that are **sampled with replacement**. As a result of the reduced variance error, the resulting 'bag' of models is more stable overall.
#
# All of the models in the bag's forecasts are combined to make the projections.
#
# ![1*JksRZ1E72Rsx2s8lQbNR1w.jpeg](https://i.ibb.co/bBPSnq2/A-Group-2-5.png)

# %%
bag_class= Pipeline([('tfidf', TfidfVectorizer()),
                     ('bag', BaggingClassifier(base_estimator = LinearSVC())),])

# %%
bag_class.fit(X_train, y_train)
# Out:
# COMET ERROR: Failed to extract parameters from estimator
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('bag', BaggingClassifier(base_estimator=LinearSVC()))])

# %%
bag_prediction = bag_class.predict(X_val) # Bagging Classifier predictions

# %%
# The classification report 
print('\nBagging Classifier  Classification report :\n', classification_report(y_val, bag_prediction,target_names=labels))
plot_confusion_matrix(y_val, voting_prediction, normalize=True,figsize=(8,8),cmap='Blues')
plt.title('Bagging Classifier Classification')
plt.show()
# Out:
# Bagging Classifier  Classification report :
#                precision    recall  f1-score   support
#
#      -1:Anti       0.72      0.46      0.56       389
#    0:Neutral       0.64      0.38      0.48       706
#        1:Pro       0.77      0.88      0.82      2559
#       2:News       0.75      0.80      0.77      1092
#
#     accuracy                           0.75      4746
#    macro avg       0.72      0.63      0.66      4746
# weighted avg       0.74      0.75      0.74      4746

# %%
# Visual represetation of of the f1 score for each class
report_bagging = classification_report(y_val, bag_prediction, output_dict=True,target_names=labels)
df_bag = pd.DataFrame(report_bagging).transpose()
df_bag.drop(['accuracy'], inplace = True)
df_bag.sort_values(by=['f1-score'],ascending=True, inplace = True)
df_bag.drop(['weighted avg','macro avg'])['f1-score'].plot(kind='barh', figsize = (8,8))
plt.xlabel('f1-score')
plt.ylabel('Classes')
plt.yticks(rotation = 40)
plt.title('f1-score per sentiment class for the voting classifier')
plt.show()

# %%
# Checking the accuracy score
bag_acc = round(accuracy_score(y_val, bag_prediction),4)
print(f'\nBagging Classifier accuracy Score :{bag_acc}')
bag_f1 = round(f1_score(y_val, bag_prediction, average="weighted"),4)
print(f'\nBagging Classifier weighted avg f1 score :{bag_f1}')
# Out:
# Bagging Classifier accuracy Score :0.7495
#
# Bagging Classifier weighted avg f1 score :0.7357

# %% [markdown]
# <a id='nine3'></a>
#
# ### 9.3 Hyperparameter Tuning
#
# We'll use the GridSearchCV approach to find the optimum hyperparameters for our models.
#
# * Models on which we will apply hyperparameter tweaking
#
#   * LinearSVC
#
#   * Logistic Regression
#
#   * Support Vector Classifier
#
# The disadvantage of using pipelines to build our models is that we can't easily get the parameters for our models. As a result, we won't be using pipelines to perform hyperparameter tuning and obtain the best parameters for our models. This means we'll have to convert raw text data to numeric using 'TifidfVectorizer' separately from building the models.

# %%
# Feature engineering
#Change 1
X_train_new= X_train.copy()
X_val_new = X_val.copy()

vectorizer = TfidfVectorizer(ngram_range=(1,20), min_df=2)
vectorizer.fit(X_train)

X_train_new = vectorizer.transform(X_train)
X_val_new = vectorizer.transform(X_val)

# %% [markdown]
# <a id='nine31'></a>
# #### 9.3.1 Tuning LinearSVC

# %%
# The hyperprarameter gridsearch for the LinearSVC is purposefully commented out because 
# it perfoms 5 folds for each of the 9 candidates totalling in 45 fits, this GridSearch code took 27 minutes to complete

#  we have saved the resulting model as a pickle file for convinience


'''
param_grid = {'C': [0.2,0.3,0.4,0.5,1.0,3,3.01,10, 100,150,200]}
# grid_lsvc = GridSearchCV(LinearSVC(),param_grid,refit=True,verbose=2)
# grid_lsvc.fit(X_train_new,y_train)

grid_lsvc = Pipeline([('tfidf', TfidfVectorizer()), ('grid', GridSearchCV(SVC(),
                                                                     param_grid,refit=True,verbose=2))])
                                                                     

grid_lsvc.fit(X_train,y_train)

# Saving the model
import pickle
model_save_path = 'LinearSVC.pkl'
with open(model_save_path, 'wb') as file:
    pickle.dump(grid_lsvc, file)
'''
# Out:
# "\nparam_grid = {'C': [0.2,0.3,0.4,0.5,1.0,3,3.01,10, 100,150,200]}\n# grid_lsvc = GridSearchCV(LinearSVC(),param_grid,refit=True,verbose=2)\n# grid_lsvc.fit(X_train_new,y_train)\n\ngrid_lsvc = Pipeline([('tfidf', TfidfVectorizer()), ('grid', GridSearchCV(SVC(),\n                                                                     param_grid,refit=True,verbose=2))])\n                                                                     \n\ngrid_lsvc.fit(X_train,y_train)\n\n# Saving the model\nimport pickle\nmodel_save_path = 'LinearSVC.pkl'\nwith open(model_save_path, 'wb') as file:\n    pickle.dump(grid_lsvc, file)\n"

# %%
 # loading the saved Logistic Regression model
model_load_path = 'LinearSVC.pkl'
with open(model_load_path, 'rb') as file:
    grid_lsvc=pickle.load(file)

# %%
tuned_lsvc_predictions = grid_lsvc.predict(X_val)

# %%
# Checking the accuracy score
tuned_lsvc_acc = round(accuracy_score(y_val, tuned_lsvc_predictions),4)
print(f'\nOverall accuracy score for LinearSVC :{tuned_lsvc_acc}')
tuned_lsvc_f1 = round(f1_score(y_val, tuned_lsvc_predictions, average="weighted"),4)
print(f'\nWeighted f1 score for LinearSVC :{tuned_lsvc_f1}')
# Out:
# Overall accuracy score for LinearSVC :0.831
#
# Weighted f1 score for LinearSVC :0.8237

# %% [markdown]
# <a id='nine32'></a>
# #### 9.3.2 Tuning Logistic Regression

# %%
# The hyperprarameter gridsearch for the logistic regression model is purposefully commented out because 
# it perfoms 5 folds for each of the 50 candidates totalling in 250 fits, this GridSearch  code took 3.6 minutes to complete
#  we have saved the resulting model as a pickle file


'''
param_grid = [
    {'penalty' : [ 'l2'],
    'C' : np.logspace(-4, 4, 50),
    'solver' : ['lbfgs']},]

Logistic_reg_grid = GridSearchCV(LogisticRegression(),param_grid,refit=True,verbose=2)
Logistic_reg_grid.fit(X_train_new, y_train)


# Saving the model
import pickle
model_save_path = 'LogisticReg.pkl'
with open(model_save_path, 'wb') as file:
    pickle.dump(logistic_grid, file)
    
  
 # loading the saved Logistic Regression model
model_load_path = 'LogisticReg.pkl'
with open(model_load_path, 'rb') as file:
    Logistic_reg_tuned=pickle.load(file)
    
'''    
param_dict = {'C': "1000", 'penalty': 'l2', "multi_class" :'ovr','solver': 'saga'}

# %%
# Retraining the Logistic Regresion model with best parameters                     
logreg_tunned = Pipeline([('tfidf', TfidfVectorizer()),('logistic', LogisticRegression(C=1000, multi_class='ovr', 
                                                                          solver='saga', random_state=11, max_iter=10)),])

# %%
logreg_tunned.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('logistic',
#                  LogisticRegression(C=1000, max_iter=10, multi_class='ovr',
#                                     random_state=11, solver='saga'))])

# %%
tunned_logreg_acc = round(accuracy_score(y_val,logreg_tunned.predict(X_val)),4)
print(f'Overall accuracy score Tuned Logistic Regression accuracy Score :{tunned_logreg_acc}')
# Out:
# Overall accuracy score Tuned Logistic Regression accuracy Score :0.7524

# %%
tunned_logreg_f1 = round(f1_score(y_val, logreg_tunned.predict(X_val), average = 'weighted'),4)
print(f'Weighted avg f1 score for Tuned Logistic Regression Classifier :{tunned_logreg_f1}')
# Out:
# Weighted avg f1 score for Tuned Logistic Regression Classifier :0.7406

# %% [markdown]
# <a id="ten"></a>
# ## 10. Final Model Selection
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Final model selection ⚡ |
# | :--------------------------- |
# | In this section we would be:we would be Comparing all the models we've built so far to choose the best performing one. |
#
# ---

# %% [markdown]
# <a id="ten1"></a>
# ### 10.1 Final evaluation of our best model

# %%
classifier_scores = {'Classifiers':['LinearSVC','LGBM','Logistic Regression','Stochastic Gradient Descent',
                                     'Voting Classifer','Bagging Classifier',
                                    'Tunned_LinearSVC','Tunned LogisticReg'],
                    'Accuracy':[linearSVC_acc,lGBM_acc,logistic_reg_acc, sgd_acc , voting_acc,
                                bag_acc,tuned_lsvc_acc ,tunned_logreg_acc],
                     'Weighted avg f1 Score':[linearSVC_f1,lGBM_f1,logistic_reg_f1, sgd_f1,
                                              voting_f1, bag_f1, tuned_lsvc_f1 ,tunned_logreg_f1]}
df= pd.DataFrame(classifier_scores)
df.sort_values(by=['Weighted avg f1 Score'],ascending=False, inplace = True)
df
# Out:
#                    Classifiers  Accuracy  Weighted avg f1 Score
# 6             Tunned_LinearSVC    0.8310                 0.8237
# 0                    LinearSVC    0.7531                 0.7406
# 7           Tunned LogisticReg    0.7524                 0.7406
# 5           Bagging Classifier    0.7495                 0.7357
# 3  Stochastic Gradient Descent    0.7450                 0.7266
# 2          Logistic Regression    0.7320                 0.7068
# 4             Voting Classifer    0.7320                 0.7068
# 1                         LGBM    0.7111                 0.6937

# %%
df.set_index(df['Classifiers'], inplace = True)
df.drop(['Classifiers'],axis = 1)
df.plot(kind='barh', figsize = (8,8),colormap='winter')
plt.xlabel('Score')
plt.yticks(rotation = 45)
plt.title('Classifier Perfomance')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %% [markdown]
# We have build a total of 8 models in this notebook out of all the models we've build, We see that the best performing model is the tunned Support Vector Classifer with the best accuracy score of 0.82 and the best weighted f1 score  of 82.
#
# We will be using the **Support Vector Classifer** to make the final prediction.

# %%
print('classfication report for our best model\n',classification_report(y_val, logreg_tunned.predict(X_val),target_names=labels))
# Out:
# classfication report for our best model
#                precision    recall  f1-score   support
#
#      -1:Anti       0.68      0.47      0.56       389
#    0:Neutral       0.64      0.40      0.49       706
#        1:Pro       0.78      0.87      0.82      2559
#       2:News       0.75      0.81      0.78      1092
#
#     accuracy                           0.75      4746
#    macro avg       0.71      0.64      0.66      4746
# weighted avg       0.74      0.75      0.74      4746

# %%
# # Visual represetation of of the f1 score for each class
report_tuned_svc = classification_report(y_val, grid_lsvc.predict(X_val), output_dict=True)
df_tuned_svc = pd.DataFrame(report_tuned_svc).transpose()
df_tuned_svc.drop(['accuracy'], inplace = True)
df_tuned_svc.sort_values(by=['f1-score'],ascending=True, inplace = True)
df_tuned_svc.drop(['weighted avg','macro avg'])['f1-score'].plot(kind='barh', figsize = (8,8))
plt.xlabel('f1-score')
plt.ylabel('Classes')
plt.yticks(rotation = 40)
plt.title('f1-score per sentiment class for tunned SVC')
plt.show()

# %% [markdown]
# <a id="ten2"></a>
# ### 10.2 ROC Curves and AUC

# %%
OneVsRest =  OneVsRestClassifier(SVC(class_weight='balanced'))
y_train_binarized = label_binarize(y_train, classes=[-1, 0, 1, 2])
y_val_binarized = label_binarize(y_val, classes=[-1, 0, 1, 2])
OneVsRest.fit(X_train_new, y_train_binarized)
y_prob = OneVsRest.decision_function(X_val_new)
plot_roc(y_val, y_prob,figsize=(10,10),cmap='cool')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %% [markdown]
# <a id="eleven"></a>
# ## 11. Final Predictions
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Final model selection ⚡ |
# | :--------------------------- |
# | In this section we would be:making our final predictions from the best non overfitted model |
#
# ---

# %%
y_pred = grid_lsvc.predict(X_test)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 2, 0, 1], dtype=int64)

# %% [markdown]
# <a id="twelve"></a>
# ## 12. Submissions
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Final model selection ⚡ |
# | :--------------------------- |
# | In this section we would be:storing our final work in a csv file |
#
# ---

# %%
test['sentiment'] = y_pred

# %%
test[['tweetid','sentiment']].to_csv('SubmissionCSV.csv', index=False)

# %%
test[['tweetid','sentiment']]
# Out:
#        tweetid  sentiment
# 0       169760          1
# 1        35326          1
# 2       224985          1
# 3       476263          1
# 4       872928          0
# ...        ...        ...
# 10541   895714          1
# 10542   875167          1
# 10543    78329          2
# 10544   867455          0
# 10545   470892          1
#
# [10546 rows x 2 columns]

# %% [markdown]
# # Closing the comet experiment

# %%
f1 = f1_score(y_val, grid_lsvc.predict(X_val), average='macro')
precision = precision_score(y_val, grid_lsvc.predict(X_val), average='macro')
recall = recall_score(y_val, grid_lsvc.predict(X_val), average='macro')

# %%
params = {"random_state": 42,
          "model_type": "logreg",
          "param_grid": str(param_dict),
          "stratify": True
          }
metrics = {"f1": f1,
           "recall": recall,
           "precision": precision
           }

experiment.log_parameters(params)
experiment.log_metrics(metrics)

# %%
# close the experiment
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/kojosbk/siders-analytics-zf5/cd888b05379f4e149f6d89b9cf63ee4a
# COMET INFO:   Metrics:
# COMET INFO:     f1        : 0.7724544835853079
# COMET INFO:     precision : 0.8413911943065302
# COMET INFO:     recall    : 0.7335567890021463
# COMET INFO:   Parameters:
# COMET INFO:     C                                                 : 1000
# COMET INFO:     LinearSVC                                         : Pipeline(steps=[('tfidf', TfidfVectorizer()), ('scv', LinearSVC())])
# COMET INFO:     LinearSVC__memory                                 : 1
# COMET INFO:     LinearSVC__scv                                    : LinearSVC()
# COMET INFO:     LinearSVC__scv__C                                 : 1.0
# COMET INFO:     LinearSVC__scv__class_weight                      : 1
# COMET INFO:     LinearSVC__scv__dual                              : True
# COMET INFO:     LinearSVC__scv__fit_intercept                     : True
# COMET INFO:     LinearSVC__scv__intercept_scaling                 : 1
# COMET INFO:     LinearSVC__scv__loss                              : squared_hinge
# COMET INFO:     LinearSVC__scv__max_iter                          : 1000
# COMET INFO:     LinearSVC__scv__multi_class                       : ovr
# COMET INFO:     LinearSVC__scv__penalty                           : l2
# COMET INFO:     LinearSVC__scv__random_state                      : 1
# COMET INFO:     LinearSVC__scv__tol                               : 0.0001
# COMET INFO:     LinearSVC__scv__verbose                           : 0
# COMET INFO:     LinearSVC__steps                                  : [('tfidf', TfidfVectorizer()), ('scv', LinearSVC())]
# COMET INFO:     LinearSVC__tfidf                                  : TfidfVectorizer()
# COMET INFO:     LinearSVC__tfidf__analyzer                        : word
# COMET INFO:     LinearSVC__tfidf__binary                          : False
# COMET INFO:     LinearSVC__tfidf__decode_error                    : strict
# COMET INFO:     LinearSVC__tfidf__dtype                           : <class 'numpy.float64'>
# COMET INFO:     LinearSVC__tfidf__encoding                        : utf-8
# COMET INFO:     LinearSVC__tfidf__input                           : content
# COMET INFO:     LinearSVC__tfidf__lowercase                       : True
# COMET INFO:     LinearSVC__tfidf__max_df                          : 1.0
# COMET INFO:     LinearSVC__tfidf__max_features                    : 1
# COMET INFO:     LinearSVC__tfidf__min_df                          : 1
# COMET INFO:     LinearSVC__tfidf__ngram_range                     : (1, 1)
# COMET INFO:     LinearSVC__tfidf__norm                            : l2
# COMET INFO:     LinearSVC__tfidf__preprocessor                    : 1
# COMET INFO:     LinearSVC__tfidf__smooth_idf                      : True
# COMET INFO:     LinearSVC__tfidf__stop_words                      : 1
# COMET INFO:     LinearSVC__tfidf__strip_accents                   : 1
# COMET INFO:     LinearSVC__tfidf__sublinear_tf                    : False
# COMET INFO:     LinearSVC__tfidf__token_pattern                   : (?u)\b\w\w+\b
# COMET INFO:     LinearSVC__tfidf__tokenizer                       : 1
# COMET INFO:     LinearSVC__tfidf__use_idf                         : True
# COMET INFO:     LinearSVC__tfidf__vocabulary                      : 1
# COMET INFO:     LinearSVC__verbose                                : False
# COMET INFO:     Logistric Regression                              : Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('logistic', LogisticRegression())])
# COMET INFO:     Logistric Regression__logistic                    : LogisticRegression()
# COMET INFO:     Logistric Regression__logistic__C                 : 1.0
# COMET INFO:     Logistric Regression__logistic__class_weight      : 1
# COMET INFO:     Logistric Regression__logistic__dual              : False
# COMET INFO:     Logistric Regression__logistic__fit_intercept     : True
# COMET INFO:     Logistric Regression__logistic__intercept_scaling : 1
# COMET INFO:     Logistric Regression__logistic__l1_ratio          : 1
# COMET INFO:     Logistric Regression__logistic__max_iter          : 100
# COMET INFO:     Logistric Regression__logistic__multi_class       : auto
# COMET INFO:     Logistric Regression__logistic__n_jobs            : 1
# COMET INFO:     Logistric Regression__logistic__penalty           : l2
# COMET INFO:     Logistric Regression__logistic__random_state      : 1
# COMET INFO:     Logistric Regression__logistic__solver            : lbfgs
# COMET INFO:     Logistric Regression__logistic__tol               : 0.0001
# COMET INFO:     Logistric Regression__logistic__verbose           : 0
# COMET INFO:     Logistric Regression__logistic__warm_start        : False
# COMET INFO:     Logistric Regression__memory                      : 1
# COMET INFO:     Logistric Regression__steps                       : [('tfidf', TfidfVectorizer()), ('logistic', LogisticRegression())]
# COMET INFO:     Logistric Regression__tfidf                       : TfidfVectorizer()
# COMET INFO:     Logistric Regression__tfidf__analyzer             : word
# COMET INFO:     Logistric Regression__tfidf__binary               : False
# COMET INFO:     Logistric Regression__tfidf__decode_error         : strict
# COMET INFO:     Logistric Regression__tfidf__dtype                : <class 'numpy.float64'>
# COMET INFO:     Logistric Regression__tfidf__encoding             : utf-8
# COMET INFO:     Logistric Regression__tfidf__input                : content
# COMET INFO:     Logistric Regression__tfidf__lowercase            : True
# COMET INFO:     Logistric Regression__tfidf__max_df               : 1.0
# COMET INFO:     Logistric Regression__tfidf__max_features         : 1
# COMET INFO:     Logistric Regression__tfidf__min_df               : 1
# COMET INFO:     Logistric Regression__tfidf__ngram_range          : (1, 1)
# COMET INFO:     Logistric Regression__tfidf__norm                 : l2
# COMET INFO:     Logistric Regression__tfidf__preprocessor         : 1
# COMET INFO:     Logistric Regression__tfidf__smooth_idf           : True
# COMET INFO:     Logistric Regression__tfidf__stop_words           : 1
# COMET INFO:     Logistric Regression__tfidf__strip_accents        : 1
# COMET INFO:     Logistric Regression__tfidf__sublinear_tf         : False
# COMET INFO:     Logistric Regression__tfidf__token_pattern        : (?u)\b\w\w+\b
# COMET INFO:     Logistric Regression__tfidf__tokenizer            : 1
# COMET INFO:     Logistric Regression__tfidf__use_idf              : True
# COMET INFO:     Logistric Regression__tfidf__vocabulary           : 1
# COMET INFO:     Logistric Regression__verbose                     : False
# COMET INFO:     SGD                                               : Pipeline(steps=[('tfidf', TfidfVectorizer()), ('SGD', SGDClassifier())])
# COMET INFO:     SGD__SGD                                          : SGDClassifier()
# COMET INFO:     SGD__SGD__alpha                                   : 0.0001
# COMET INFO:     SGD__SGD__average                                 : False
# COMET INFO:     SGD__SGD__class_weight                            : 1
# COMET INFO:     SGD__SGD__early_stopping                          : False
# COMET INFO:     SGD__SGD__epsilon                                 : 0.1
# COMET INFO:     SGD__SGD__eta0                                    : 0.0
# COMET INFO:     SGD__SGD__fit_intercept                           : True
# COMET INFO:     SGD__SGD__l1_ratio                                : 0.15
# COMET INFO:     SGD__SGD__learning_rate                           : optimal
# COMET INFO:     SGD__SGD__loss                                    : hinge
# COMET INFO:     SGD__SGD__max_iter                                : 1000
# COMET INFO:     SGD__SGD__n_iter_no_change                        : 5
# COMET INFO:     SGD__SGD__n_jobs                                  : 1
# COMET INFO:     SGD__SGD__penalty                                 : l2
# COMET INFO:     SGD__SGD__power_t                                 : 0.5
# COMET INFO:     SGD__SGD__random_state                            : 1
# COMET INFO:     SGD__SGD__shuffle                                 : True
# COMET INFO:     SGD__SGD__tol                                     : 0.001
# COMET INFO:     SGD__SGD__validation_fraction                     : 0.1
# COMET INFO:     SGD__SGD__verbose                                 : 0
# COMET INFO:     SGD__SGD__warm_start                              : False
# COMET INFO:     SGD__alpha                                        : 0.0001
# COMET INFO:     SGD__average                                      : False
# COMET INFO:     SGD__class_weight                                 : 1
# COMET INFO:     SGD__early_stopping                               : False
# COMET INFO:     SGD__epsilon                                      : 0.1
# COMET INFO:     SGD__eta0                                         : 0.0
# COMET INFO:     SGD__fit_intercept                                : True
# COMET INFO:     SGD__l1_ratio                                     : 0.15
# COMET INFO:     SGD__learning_rate                                : optimal
# COMET INFO:     SGD__loss                                         : hinge
# COMET INFO:     SGD__max_iter                                     : 1000
# COMET INFO:     SGD__memory                                       : 1
# COMET INFO:     SGD__n_iter_no_change                             : 5
# COMET INFO:     SGD__n_jobs                                       : 1
# COMET INFO:     SGD__penalty                                      : l2
# COMET INFO:     SGD__power_t                                      : 0.5
# COMET INFO:     SGD__random_state                                 : 1
# COMET INFO:     SGD__shuffle                                      : True
# COMET INFO:     SGD__steps                                        : [('tfidf', TfidfVectorizer()), ('SGD', SGDClassifier())]
# COMET INFO:     SGD__tfidf                                        : TfidfVectorizer()
# COMET INFO:     SGD__tfidf__analyzer                              : word
# COMET INFO:     SGD__tfidf__binary                                : False
# COMET INFO:     SGD__tfidf__decode_error                          : strict
# COMET INFO:     SGD__tfidf__dtype                                 : <class 'numpy.float64'>
# COMET INFO:     SGD__tfidf__encoding                              : utf-8
# COMET INFO:     SGD__tfidf__input                                 : content
# COMET INFO:     SGD__tfidf__lowercase                             : True
# COMET INFO:     SGD__tfidf__max_df                                : 1.0
# COMET INFO:     SGD__tfidf__max_features                          : 1
# COMET INFO:     SGD__tfidf__min_df                                : 1
# COMET INFO:     SGD__tfidf__ngram_range                           : (1, 1)
# COMET INFO:     SGD__tfidf__norm                                  : l2
# COMET INFO:     SGD__tfidf__preprocessor                          : 1
# COMET INFO:     SGD__tfidf__smooth_idf                            : True
# COMET INFO:     SGD__tfidf__stop_words                            : 1
# COMET INFO:     SGD__tfidf__strip_accents                         : 1
# COMET INFO:     SGD__tfidf__sublinear_tf                          : False
# COMET INFO:     SGD__tfidf__token_pattern                         : (?u)\b\w\w+\b
# COMET INFO:     SGD__tfidf__tokenizer                             : 1
# COMET INFO:     SGD__tfidf__use_idf                               : True
# COMET INFO:     SGD__tfidf__vocabulary                            : 1
# COMET INFO:     SGD__tol                                          : 0.001
# COMET INFO:     SGD__validation_fraction                          : 0.1
# COMET INFO:     SGD__verbose                                      : 0
# COMET INFO:     SGD__warm_start                                   : False
# COMET INFO:     SGD_alpha                                         : 0.0001
# COMET INFO:     SGD_average                                       : False
# COMET INFO:     SGD_class_weight                                  : 1
# COMET INFO:     SGD_early_stopping                                : False
# COMET INFO:     SGD_epsilon                                       : 0.1
# COMET INFO:     SGD_eta0                                          : 0.0
# COMET INFO:     SGD_fit_intercept                                 : True
# COMET INFO:     SGD_l1_ratio                                      : 0.15
# COMET INFO:     SGD_learning_rate                                 : optimal
# COMET INFO:     SGD_loss                                          : hinge
# COMET INFO:     SGD_max_iter                                      : 1000
# COMET INFO:     SGD_n_iter_no_change                              : 5
# COMET INFO:     SGD_n_jobs                                        : 1
# COMET INFO:     SGD_penalty                                       : l2
# COMET INFO:     SGD_power_t                                       : 0.5
# COMET INFO:     SGD_random_state                                  : 1
# COMET INFO:     SGD_shuffle                                       : True
# COMET INFO:     SGD_tol                                           : 0.001
# COMET INFO:     SGD_validation_fraction                           : 0.1
# COMET INFO:     SGD_verbose                                       : 0
# COMET INFO:     SGD_warm_start                                    : False
# COMET INFO:     alpha                                             : 0.0001
# COMET INFO:     analyzer                                          : word
# COMET INFO:     average                                           : False
# COMET INFO:     bag                                               : BaggingClassifier(base_estimator=LinearSVC())
# COMET INFO:     bag__base_estimator                               : LinearSVC()
# COMET INFO:     bag__base_estimator__C                            : 1.0
# COMET INFO:     bag__base_estimator__class_weight                 : 1
# COMET INFO:     bag__base_estimator__dual                         : True
# COMET INFO:     bag__base_estimator__fit_intercept                : True
# COMET INFO:     bag__base_estimator__intercept_scaling            : 1
# COMET INFO:     bag__base_estimator__loss                         : squared_hinge
# COMET INFO:     bag__base_estimator__max_iter                     : 1000
# COMET INFO:     bag__base_estimator__multi_class                  : ovr
# COMET INFO:     bag__base_estimator__penalty                      : l2
# COMET INFO:     bag__base_estimator__random_state                 : 1
# COMET INFO:     bag__base_estimator__tol                          : 0.0001
# COMET INFO:     bag__base_estimator__verbose                      : 0
# COMET INFO:     bag__bootstrap                                    : True
# COMET INFO:     bag__bootstrap_features                           : False
# COMET INFO:     bag__max_features                                 : 1.0
# COMET INFO:     bag__max_samples                                  : 1.0
# COMET INFO:     bag__n_estimators                                 : 10
# COMET INFO:     bag__n_jobs                                       : 1
# COMET INFO:     bag__oob_score                                    : False
# COMET INFO:     bag__random_state                                 : 1
# COMET INFO:     bag__verbose                                      : 0
# COMET INFO:     bag__warm_start                                   : False
# COMET INFO:     bag_base_estimator                                : LinearSVC()
# COMET INFO:     bag_base_estimator__C                             : 1.0
# COMET INFO:     bag_base_estimator__class_weight                  : 1
# COMET INFO:     bag_base_estimator__dual                          : True
# COMET INFO:     bag_base_estimator__fit_intercept                 : True
# COMET INFO:     bag_base_estimator__intercept_scaling             : 1
# COMET INFO:     bag_base_estimator__loss                          : squared_hinge
# COMET INFO:     bag_base_estimator__max_iter                      : 1000
# COMET INFO:     bag_base_estimator__multi_class                   : ovr
# COMET INFO:     bag_base_estimator__penalty                       : l2
# COMET INFO:     bag_base_estimator__random_state                  : 1
# COMET INFO:     bag_base_estimator__tol                           : 0.0001
# COMET INFO:     bag_base_estimator__verbose                       : 0
# COMET INFO:     bag_bootstrap                                     : True
# COMET INFO:     bag_bootstrap_features                            : False
# COMET INFO:     bag_max_features                                  : 1.0
# COMET INFO:     bag_max_samples                                   : 1.0
# COMET INFO:     bag_n_estimators                                  : 10
# COMET INFO:     bag_n_jobs                                        : 1
# COMET INFO:     bag_oob_score                                     : False
# COMET INFO:     bag_random_state                                  : 1
# COMET INFO:     bag_verbose                                       : 0
# COMET INFO:     bag_warm_start                                    : False
# COMET INFO:     base_estimator                                    : LinearSVC()
# COMET INFO:     base_estimator__C                                 : 1.0
# COMET INFO:     base_estimator__class_weight                      : 1
# COMET INFO:     base_estimator__dual                              : True
# COMET INFO:     base_estimator__fit_intercept                     : True
# COMET INFO:     base_estimator__intercept_scaling                 : 1
# COMET INFO:     base_estimator__loss                              : squared_hinge
# COMET INFO:     base_estimator__max_iter                          : 1000
# COMET INFO:     base_estimator__multi_class                       : ovr
# COMET INFO:     base_estimator__penalty                           : l2
# COMET INFO:     base_estimator__random_state                      : 1
# COMET INFO:     base_estimator__tol                               : 0.0001
# COMET INFO:     base_estimator__verbose                           : 0
# COMET INFO:     binary                                            : False
# COMET INFO:     boosting_type                                     : gbdt
# COMET INFO:     bootstrap                                         : True
# COMET INFO:     bootstrap_features                                : False
# COMET INFO:     class_weight                                      : 1
# COMET INFO:     colsample_bytree                                  : 1.0
# COMET INFO:     decode_error                                      : strict
# COMET INFO:     dtype                                             : <class 'numpy.float64'>
# COMET INFO:     dual                                              : False
# COMET INFO:     early_stopping                                    : False
# COMET INFO:     early_stopping_round                              : 1
# COMET INFO:     encoding                                          : utf-8
# COMET INFO:     epsilon                                           : 0.1
# COMET INFO:     estimators                                        : [('LinearSVC', Pipeline(steps=[('tfidf', TfidfVectorizer()), ('scv', LinearSVC())])), ('SGD', Pipeline(steps=[('tfidf', TfidfVectorizer()), ('SGD', SGDClassifier())])), ('Logistric Regression', Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('logistic', LogisticRegression())]))]
# COMET INFO:     eta0                                              : 0.0
# COMET INFO:     fit_intercept                                     : True
# COMET INFO:     flatten_transform                                 : True
# COMET INFO:     input                                             : content
# COMET INFO:     intercept_scaling                                 : 1
# COMET INFO:     l1_ratio                                          : 3
# COMET INFO:     learning_rate                                     : optimal
# COMET INFO:     lgbm                                              : LGBMClassifier()
# COMET INFO:     lgbm__boosting_type                               : gbdt
# COMET INFO:     lgbm__class_weight                                : 1
# COMET INFO:     lgbm__colsample_bytree                            : 1.0
# COMET INFO:     lgbm__importance_type                             : split
# COMET INFO:     lgbm__learning_rate                               : 0.1
# COMET INFO:     lgbm__max_depth                                   : -1
# COMET INFO:     lgbm__min_child_samples                           : 20
# COMET INFO:     lgbm__min_child_weight                            : 0.001
# COMET INFO:     lgbm__min_split_gain                              : 0.0
# COMET INFO:     lgbm__n_estimators                                : 100
# COMET INFO:     lgbm__n_jobs                                      : -1
# COMET INFO:     lgbm__num_leaves                                  : 31
# COMET INFO:     lgbm__objective                                   : 1
# COMET INFO:     lgbm__random_state                                : 1
# COMET INFO:     lgbm__reg_alpha                                   : 0.0
# COMET INFO:     lgbm__reg_lambda                                  : 0.0
# COMET INFO:     lgbm__silent                                      : warn
# COMET INFO:     lgbm__subsample                                   : 1.0
# COMET INFO:     lgbm__subsample_for_bin                           : 200000
# COMET INFO:     lgbm__subsample_freq                              : 0
# COMET INFO:     lgbm_boosting_type                                : gbdt
# COMET INFO:     lgbm_class_weight                                 : 1
# COMET INFO:     lgbm_colsample_bytree                             : 1.0
# COMET INFO:     lgbm_importance_type                              : split
# COMET INFO:     lgbm_learning_rate                                : 0.1
# COMET INFO:     lgbm_max_depth                                    : -1
# COMET INFO:     lgbm_min_child_samples                            : 20
# COMET INFO:     lgbm_min_child_weight                             : 0.001
# COMET INFO:     lgbm_min_split_gain                               : 0.0
# COMET INFO:     lgbm_n_estimators                                 : 100
# COMET INFO:     lgbm_n_jobs                                       : -1
# COMET INFO:     lgbm_num_leaves                                   : 31
# COMET INFO:     lgbm_objective                                    : 1
# COMET INFO:     lgbm_random_state                                 : 1
# COMET INFO:     lgbm_reg_alpha                                    : 0.0
# COMET INFO:     lgbm_reg_lambda                                   : 0.0
# COMET INFO:     lgbm_silent                                       : warn
# COMET INFO:     lgbm_subsample                                    : 1.0
# COMET INFO:     lgbm_subsample_for_bin                            : 200000
# COMET INFO:     lgbm_subsample_freq                               : 0
# COMET INFO:     logistic                                          : LogisticRegression(C=1000, max_iter=10, multi_class='ovr', random_state=11,
#                    solver='saga')
# COMET INFO:     logistic_C                                        : 1000
# COMET INFO:     logistic__C                                       : 1000
# COMET INFO:     logistic__class_weight                            : 1
# COMET INFO:     logistic__dual                                    : False
# COMET INFO:     logistic__fit_intercept                           : True
# COMET INFO:     logistic__intercept_scaling                       : 1
# COMET INFO:     logistic__l1_ratio                                : 1
# COMET INFO:     logistic__max_iter                                : 10
# COMET INFO:     logistic__multi_class                             : ovr
# COMET INFO:     logistic__n_jobs                                  : 1
# COMET INFO:     logistic__penalty                                 : l2
# COMET INFO:     logistic__random_state                            : 11
# COMET INFO:     logistic__solver                                  : saga
# COMET INFO:     logistic__tol                                     : 0.0001
# COMET INFO:     logistic__verbose                                 : 0
# COMET INFO:     logistic__warm_start                              : False
# COMET INFO:     logistic_class_weight                             : 1
# COMET INFO:     logistic_dual                                     : False
# COMET INFO:     logistic_fit_intercept                            : True
# COMET INFO:     logistic_intercept_scaling                        : 1
# COMET INFO:     logistic_l1_ratio                                 : 1
# COMET INFO:     logistic_max_iter                                 : 10
# COMET INFO:     logistic_multi_class                              : ovr
# COMET INFO:     logistic_n_jobs                                   : 1
# COMET INFO:     logistic_penalty                                  : l2
# COMET INFO:     logistic_random_state                             : 11
# COMET INFO:     logistic_solver                                   : saga
# COMET INFO:     logistic_tol                                      : 0.0001
# COMET INFO:     logistic_verbose                                  : 0
# COMET INFO:     logistic_warm_start                               : False
# COMET INFO:     loss                                              : squared_hinge
# COMET INFO:     lowercase                                         : True
# COMET INFO:     max_depth                                         : -1
# COMET INFO:     max_df                                            : 1.0
# COMET INFO:     max_features                                      : 2
# COMET INFO:     max_iter                                          : 10
# COMET INFO:     max_samples                                       : 1.0
# COMET INFO:     memory                                            : 1
# COMET INFO:     metric                                            : ['multiclass']
# COMET INFO:     min_child_samples                                 : 20
# COMET INFO:     min_child_weight                                  : 0.001
# COMET INFO:     min_df                                            : 2
# COMET INFO:     min_split_gain                                    : 0.0
# COMET INFO:     model_type                                        : logreg
# COMET INFO:     multi_class                                       : ovr
# COMET INFO:     n_estimators                                      : 10
# COMET INFO:     n_iter_no_change                                  : 5
# COMET INFO:     n_jobs                                            : 2
# COMET INFO:     ngram_range                                       : (1, 20)
# COMET INFO:     norm                                              : l2
# COMET INFO:     num_class                                         : 4
# COMET INFO:     num_iterations                                    : 100
# COMET INFO:     num_leaves                                        : 31
# COMET INFO:     objective                                         : multiclass
# COMET INFO:     oob_score                                         : False
# COMET INFO:     param_grid                                        : {'C': '1000', 'penalty': 'l2', 'multi_class': 'ovr', 'solver': 'saga'}
# COMET INFO:     penalty                                           : l2
# COMET INFO:     power_t                                           : 0.5
# COMET INFO:     preprocessor                                      : 1
# COMET INFO:     random_state                                      : 42
# COMET INFO:     reg_alpha                                         : 0.0
# COMET INFO:     reg_lambda                                        : 0.0
# COMET INFO:     scv                                               : LinearSVC()
# COMET INFO:     scv_C                                             : 1.0
# COMET INFO:     scv__C                                            : 1.0
# COMET INFO:     scv__class_weight                                 : 1
# COMET INFO:     scv__dual                                         : True
# COMET INFO:     scv__fit_intercept                                : True
# COMET INFO:     scv__intercept_scaling                            : 1
# COMET INFO:     scv__loss                                         : squared_hinge
# COMET INFO:     scv__max_iter                                     : 1000
# COMET INFO:     scv__multi_class                                  : ovr
# COMET INFO:     scv__penalty                                      : l2
# COMET INFO:     scv__random_state                                 : 1
# COMET INFO:     scv__tol                                          : 0.0001
# COMET INFO:     scv__verbose                                      : 0
# COMET INFO:     scv_class_weight                                  : 1
# COMET INFO:     scv_dual                                          : True
# COMET INFO:     scv_fit_intercept                                 : True
# COMET INFO:     scv_intercept_scaling                             : 1
# COMET INFO:     scv_loss                                          : squared_hinge
# COMET INFO:     scv_max_iter                                      : 1000
# COMET INFO:     scv_multi_class                                   : ovr
# COMET INFO:     scv_penalty                                       : l2
# COMET INFO:     scv_random_state                                  : 1
# COMET INFO:     scv_tol                                           : 0.0001
# COMET INFO:     scv_verbose                                       : 0
# COMET INFO:     shuffle                                           : True
# COMET INFO:     smooth_idf                                        : True
# COMET INFO:     solver                                            : saga
# COMET INFO:     steps                                             : [('tfidf', TfidfVectorizer()), ('logistic', LogisticRegression(C=1000, max_iter=10, multi_class='ovr', random_state=11,
#                    solver='saga'))]
# COMET INFO:     stop_words                                        : 1
# COMET INFO:     stratify                                          : True
# COMET INFO:     strip_accents                                     : 1
# COMET INFO:     sublinear_tf                                      : False
# COMET INFO:     subsample                                         : 1.0
# COMET INFO:     subsample_for_bin                                 : 200000
# COMET INFO:     subsample_freq                                    : 0
# COMET INFO:     tfidf                                             : TfidfVectorizer()
# COMET INFO:     tfidf__analyzer                                   : word
# COMET INFO:     tfidf__binary                                     : False
# COMET INFO:     tfidf__decode_error                               : strict
# COMET INFO:     tfidf__dtype                                      : <class 'numpy.float64'>
# COMET INFO:     tfidf__encoding                                   : utf-8
# COMET INFO:     tfidf__input                                      : content
# COMET INFO:     tfidf__lowercase                                  : True
# COMET INFO:     tfidf__max_df                                     : 1.0
# COMET INFO:     tfidf__max_features                               : 1
# COMET INFO:     tfidf__min_df                                     : 1
# COMET INFO:     tfidf__ngram_range                                : (1, 1)
# COMET INFO:     tfidf__norm                                       : l2
# COMET INFO:     tfidf__preprocessor                               : 1
# COMET INFO:     tfidf__smooth_idf                                 : True
# COMET INFO:     tfidf__stop_words                                 : 1
# COMET INFO:     tfidf__strip_accents                              : 1
# COMET INFO:     tfidf__sublinear_tf                               : False
# COMET INFO:     tfidf__token_pattern                              : (?u)\b\w\w+\b
# COMET INFO:     tfidf__tokenizer                                  : 1
# COMET INFO:     tfidf__use_idf                                    : True
# COMET INFO:     tfidf__vocabulary                                 : 1
# COMET INFO:     tfidf_analyzer                                    : word
# COMET INFO:     tfidf_binary                                      : False
# COMET INFO:     tfidf_decode_error                                : strict
# COMET INFO:     tfidf_dtype                                       : <class 'numpy.float64'>
# COMET INFO:     tfidf_encoding                                    : utf-8
# COMET INFO:     tfidf_input                                       : content
# COMET INFO:     tfidf_lowercase                                   : True
# COMET INFO:     tfidf_max_df                                      : 1.0
# COMET INFO:     tfidf_max_features                                : 1
# COMET INFO:     tfidf_min_df                                      : 1
# COMET INFO:     tfidf_ngram_range                                 : (1, 1)
# COMET INFO:     tfidf_norm                                        : l2
# COMET INFO:     tfidf_preprocessor                                : 1
# COMET INFO:     tfidf_smooth_idf                                  : True
# COMET INFO:     tfidf_stop_words                                  : 1
# COMET INFO:     tfidf_strip_accents                               : 1
# COMET INFO:     tfidf_sublinear_tf                                : False
# COMET INFO:     tfidf_token_pattern                               : (?u)\b\w\w+\b
# COMET INFO:     tfidf_tokenizer                                   : 1
# COMET INFO:     tfidf_use_idf                                     : True
# COMET INFO:     tfidf_vocabulary                                  : 1
# COMET INFO:     token_pattern                                     : (?u)\b\w\w+\b
# COMET INFO:     tokenizer                                         : 1
# COMET INFO:     tol                                               : 0.0001
# COMET INFO:     use_idf                                           : True
# COMET INFO:     validation_fraction                               : 0.1
# COMET INFO:     verbose                                           : False
# COMET INFO:     vocabulary                                        : 1
# COMET INFO:     voting                                            : hard
# COMET INFO:     warm_start                                        : False
# COMET INFO:     weights                                           : [0.1 0.3 0.6]
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (7.18 MB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO: ---------------------------
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The Python SDK has 3600 seconds to finish before aborting...
# COMET INFO: Uploading 4 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: Still uploading 2 file(s), remaining 7.69 KB/3.33 MB

# %%
experiment.display()
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://www.comet.ml/kojosbk/siders-analytics-zf5/cd888b05379f4e149f6d89b9cf63ee4a"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a id="thirteen"></a>
# ## 13. Conclusion
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Final model selection ⚡ |
# | :--------------------------- |
# | In this section we would be:making our final predictions from the best non overfitted model |
#
# ---

# %% [markdown]
# With a f1 score of 0.87 for the "Pro climate change" sentiment class, followed by f1 scores of 0.84 and 0.70 for the "News" and "Anti" Climate sentiment classes, respectively, the Tuneed linear SVC is by far our best performing model. This is impressive considering how poorly all of our models classified the "Anti climate change" sentiment class.

# %% [markdown]
# <a id='references'></a>
# # References
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# * TF-IDF Explained And Python Sklearn Implementation :
# https://towardsdatascience.com/tf-idf-explained-and-python-sklearn-implementation-b020c5e83275
#
# * Decision Trees Explained Easily :
# https://medium.com/@chiragsehra42/decision-trees-explained-easily-28f23241248
#
# * Understanding Random Forests Classifiers in Python :
# https://www.datacamp.com/community/tutorials/random-forests-classifier-python
#
# * What is LightGBM, How to implement it? How to fine tune the parameters?
# https://medium.com/@pushkarmandot/https-medium-com-pushkarmandot-what-is-lightgbm-how-to-implement-it-how-to-fine-tune-the-parameters-60347819b7fc
#
# * How to make SGD Classifier perform as well as Logistic Regression
# https://towardsdatascience.com/how-to-make-sgd-classifier-perform-as-well-as-logistic-regression-using-parfit-cc10bca2d3c4
